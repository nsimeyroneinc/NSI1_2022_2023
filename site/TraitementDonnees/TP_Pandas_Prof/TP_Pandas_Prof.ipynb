# %% [markdown]
# <table  style="table-layout: fixed;background-color:#87A96B; border:solid;color:black;width:100%;">
#         <tr>
#             <th colspan=2; style="background-color: #3B444B;color:white;text-align:center;border:none;font-size:12pt;">
#            Thème : Traitement des données
#             </th>
#         </tr>
# </table>
# <table  style="table-layout: fixed;background-color:#87A96B; border:solid;color:black;width:100%;">
#         <tr >
#             <th width="25%"; style="background-color: #3B444B;color:white;text-align:center;border:none;font-size:50pt;">
#             20
#             </th>
#             <th  width="75%"; style="text-align:center;background-color:#99BADD;border:none;font-size:25pt;">Manipulation de fichiers CSV avec la bibliothèque Pandas</th>
#         </tr>
# </table>

# %% [markdown]
# Le module `csv` utilisé précédemment se contente de lire les données structurées. Il ne fait aucun effort particulier pour analyser les données. Nous nous en sommes aperçus lorsqu'il a fallu convertir par `int()` toutes les valeurs numériques, qui étaient interprétées comme des chaînes de caractères.
# La bibliothèque `pandas` est par contre spécialement conçue pour l'analyse des données (*data analysis*) : elle est donc naturellement bien plus performante.

# %% [markdown]
# Nous allons utiliser une base de données sur les joueurs NBA.

# %%
import pandas as pd #import du module pandas, abrégé classiquement par "pd"

# %%
df = pd.read_csv('data/players.csv', encoding = 'utf-8')

# %% [markdown]
# La variable est nommée classiquement `df` pour *dataframe* (que l'on peut traduire par *table de données*)

# %% [markdown]
# # Premiers renseignements sur les fichiers de données
#
# Que contient la variable `df`?

# %%
df
# Out:
#                  Name Position            Team  Age  Height Height_i  Weight  \
# 0      Juhann Begarin       SG  Boston Celtics   19   6' 5"      6-5     185
# 1        Jaylen Brown       SG  Boston Celtics   24   6' 6"      6-6     223
# 2           Kris Dunn       PG  Boston Celtics   27   6' 3"      6-3     205
# 3      Carsen Edwards       PG  Boston Celtics   23  5' 11"     5-11     200
# 4          Tacko Fall        C  Boston Celtics   25   7' 5"      7-5     311
# ..                ...      ...             ...  ...     ...      ...     ...
# 553      Juwan Morgan       SF       Utah Jazz   24   6' 7"      6-7     232
# 554     Royce O'Neale       PF       Utah Jazz   28   6' 4"      6-4     226
# 555       Olumiye Oni       SG       Utah Jazz   24   6' 5"      6-5     206
# 556     Eric Paschall        F       Utah Jazz   24   6' 6"      6-6     255
# 557  Hassan Whiteside        C       Utah Jazz   32   7' 0"      7-0     265
#
#         College      Salary  Points  Rebounds  Assists
# 0           NaN         NaN     NaN       NaN      NaN
# 1    California  26758928.0    24.7       6.0      3.4
# 2    Providence   5005350.0     1.3       1.5      0.5
# 3        Purdue   1782621.0     4.0       0.8      0.5
# 4           UCF         NaN     2.5       2.7      0.2
# ..          ...         ...     ...       ...      ...
# 553     Indiana         NaN     1.2       1.0      0.3
# 554      Baylor   8800000.0     7.0       6.8      2.5
# 555        Yale   1782621.0     NaN       NaN      NaN
# 556   Villanova   1782621.0     9.5       3.2      1.3
# 557    Marshall   1669178.0     8.1       6.0      0.6
#
# [558 rows x 12 columns]

# %% [markdown]
# Les données sont présentées dans l'ordre originel du fichier.
#
# &#x27A1; Il est possible d'avoir uniquement les premières lignes du fichier avec la commande `head()` et les dernières du fichier avec la commande `tail()`. Ces commandes peuvent recevoir en paramètre un nombre entier.

# %%
df.head()
# Out:
#              Name Position            Team  Age  Height Height_i  Weight  \
# 0  Juhann Begarin       SG  Boston Celtics   19   6' 5"      6-5     185
# 1    Jaylen Brown       SG  Boston Celtics   24   6' 6"      6-6     223
# 2       Kris Dunn       PG  Boston Celtics   27   6' 3"      6-3     205
# 3  Carsen Edwards       PG  Boston Celtics   23  5' 11"     5-11     200
# 4      Tacko Fall        C  Boston Celtics   25   7' 5"      7-5     311
#
#       College      Salary  Points  Rebounds  Assists
# 0         NaN         NaN     NaN       NaN      NaN
# 1  California  26758928.0    24.7       6.0      3.4
# 2  Providence   5005350.0     1.3       1.5      0.5
# 3      Purdue   1782621.0     4.0       0.8      0.5
# 4         UCF         NaN     2.5       2.7      0.2

# %%
df.tail()
# Out:
#                  Name Position       Team  Age Height Height_i  Weight  \
# 553      Juwan Morgan       SF  Utah Jazz   24  6' 7"      6-7     232
# 554     Royce O'Neale       PF  Utah Jazz   28  6' 4"      6-4     226
# 555       Olumiye Oni       SG  Utah Jazz   24  6' 5"      6-5     206
# 556     Eric Paschall        F  Utah Jazz   24  6' 6"      6-6     255
# 557  Hassan Whiteside        C  Utah Jazz   32  7' 0"      7-0     265
#
#        College     Salary  Points  Rebounds  Assists
# 553    Indiana        NaN     1.2       1.0      0.3
# 554     Baylor  8800000.0     7.0       6.8      2.5
# 555       Yale  1782621.0     NaN       NaN      NaN
# 556  Villanova  1782621.0     9.5       3.2      1.3
# 557   Marshall  1669178.0     8.1       6.0      0.6

# %%
df.head(3)
# Out:
#              Name Position            Team  Age Height Height_i  Weight  \
# 0  Juhann Begarin       SG  Boston Celtics   19  6' 5"      6-5     185
# 1    Jaylen Brown       SG  Boston Celtics   24  6' 6"      6-6     223
# 2       Kris Dunn       PG  Boston Celtics   27  6' 3"      6-3     205
#
#       College      Salary  Points  Rebounds  Assists
# 0         NaN         NaN     NaN       NaN      NaN
# 1  California  26758928.0    24.7       6.0      3.4
# 2  Providence   5005350.0     1.3       1.5      0.5

# %%
df.tail(5)
# Out:
#                  Name Position       Team  Age Height Height_i  Weight  \
# 553      Juwan Morgan       SF  Utah Jazz   24  6' 7"      6-7     232
# 554     Royce O'Neale       PF  Utah Jazz   28  6' 4"      6-4     226
# 555       Olumiye Oni       SG  Utah Jazz   24  6' 5"      6-5     206
# 556     Eric Paschall        F  Utah Jazz   24  6' 6"      6-6     255
# 557  Hassan Whiteside        C  Utah Jazz   32  7' 0"      7-0     265
#
#        College     Salary  Points  Rebounds  Assists
# 553    Indiana        NaN     1.2       1.0      0.3
# 554     Baylor  8800000.0     7.0       6.8      2.5
# 555       Yale  1782621.0     NaN       NaN      NaN
# 556  Villanova  1782621.0     9.5       3.2      1.3
# 557   Marshall  1669178.0     8.1       6.0      0.6

# %% [markdown]
# &#x27A1; Pour avoir des renseignements globaux sur la structure de notre fichier, on peut utiliser la commande `df.info()`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558 entries, 0 to 557
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      558 non-null    object
#  1   Position  558 non-null    object
#  2   Team      558 non-null    object
#  3   Age       558 non-null    int64
#  4   Height    558 non-null    object
#  5   Height_i  558 non-null    object
#  6   Weight    558 non-null    int64
#  7   College   485 non-null    object
#  8   Salary    445 non-null    float64
#  9   Points    476 non-null    float64
#  10  Rebounds  476 non-null    float64
#  11  Assists   476 non-null    float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 52.4+ KB

# %% [markdown]
# # Extraction de colonnes
#
# ## Pour accéder aux information d'une colonne
#
# ### Filter les lignes en appliquant une condition aux colonnes à l'aide de  `.loc`

# %% [markdown]
# &#x27A1; Pour faire afficher une colonne de données :

# %%
df.loc[:,"Salary"]
# Out:
# 0             NaN
# 1      26758928.0
# 2       5005350.0
# 3       1782621.0
# 4             NaN
#           ...
# 553           NaN
# 554     8800000.0
# 555     1782621.0
# 556     1782621.0
# 557     1669178.0
# Name: Salary, Length: 558, dtype: float64

# %% [markdown]
# &#x27A1;  On peut rajouter une contrainte avec, par exemple; uniquement les 10 premiers de la liste

# %%
df.loc[:10,"Salary"]  # les 10 premiers dans la liste
# Out:
# 0            NaN
# 1     26758928.0
# 2      5005350.0
# 3      1782621.0
# 4            NaN
# 5      1782621.0
# 6     27000000.0
# 7      1669178.0
# 8            NaN
# 9      3804360.0
# 10     3631200.0
# Name: Salary, dtype: float64

# %%
df.loc[10]  # les 10 premiers dans la liste
# Out:
# Name         Aaron Nesmith
# Position                SF
# Team        Boston Celtics
# Age                     21
# Height               6' 5"
# Height_i               6-5
# Weight                 215
# College         Vanderbilt
# Salary           3631200.0
# Points                 4.7
# Rebounds               2.8
# Assists                0.5
# Name: 10, dtype: object

# %% [markdown]
# **&#x1F58B; A vous**
# Faite apparaitre la colonne correspondant au âge des joueurs, puis faite apparaitre les 15 premiers de la liste.

# %%
df.loc[:15,"Salary"]
# Out:
# 0            NaN
# 1     26758928.0
# 2      5005350.0
# 3      1782621.0
# 4            NaN
# 5      1782621.0
# 6     27000000.0
# 7      1669178.0
# 8            NaN
# 9      3804360.0
# 10     3631200.0
# 11     2283034.0
# 12     2137440.0
# 13    11615328.0
# 14     5890000.0
# 15    14339285.0
# Name: Salary, dtype: float64

# %% [markdown]
# &#x27A1; Pour accéder à une fiche particulière de joueur avec sa position, on peut utiliser la fonction `loc()` :

# %%
test=df.loc[45]
print(test)
test1=df.loc[45,['Name','Position']]
print(test1)
# Out:
# Name             RJ Barrett
# Position                 SG
# Team        New York Knicks
# Age                      21
# Height                6' 6"
# Height_i                6.6
# Weight                  214
# College                Duke
# Salary            8623920.0
# Points                 17.6
# Rebounds                5.8
# Assists                 3.0
# Name: 45, dtype: object
# Name        RJ Barrett
# Position            SG
# Name: 45, dtype: object

# %% [markdown]
# ### Extraire des informations selon des critères  `loc()`
#
# &#x27A1; Cette méthode nécessite de savoir la position du joueur voulu, pour accéder à un joueur avec son nom :

# %%
df.loc[df['Name']=='Kevin Durant']   # ou df.loc[df.Name=='Kevin Durant']
# Out:
#             Name Position           Team  Age  Height  Height_i  Weight  \
# 25  Kevin Durant       PF  Brooklyn Nets   32  6' 10"       6.1     240
#
#    College      Salary  Points  Rebounds  Assists
# 25   Texas  42018900.0    26.9       7.1      5.6

# %% [markdown]
# &#x27A1; Pour accéder à des données avec une contrainte (Joueurs touchant plus de 40 millions de dollars par an):

# %%
df.loc[df.Salary>=40000000]
# Out:
#                   Name Position                   Team  Age  Height  Height_i  \
# 25        Kevin Durant       PF          Brooklyn Nets   32  6' 10"       6.1
# 29        James Harden       SG          Brooklyn Nets   32   6' 5"       6.5
# 287      Stephen Curry       PG  Golden State Warriors   33   6' 3"       6.3
# 331       LeBron James       SF     Los Angeles Lakers   36   6' 9"       6.9
# 336  Russell Westbrook       PG     Los Angeles Lakers   32   6' 3"       6.3
# 408          John Wall       PG        Houston Rockets   31   6' 3"       6.3
#
#      Weight        College      Salary  Points  Rebounds  Assists
# 25      240          Texas  42018900.0    26.9       7.1      5.6
# 29      220  Arizona State  44310840.0    24.6       7.9     10.8
# 287     185       Davidson  45780966.0    32.0       5.5      5.8
# 331     250            NaN  41180544.0    25.0       7.7      7.8
# 336     200           UCLA  44211146.0    22.2      11.5     11.7
# 408     210       Kentucky  44310840.0    20.6       3.2      6.9

# %% [markdown]
# **&#x1F58B; A vous**
# Donner les joueurs marquant plus de 25 points par match.

# %%
df.loc[df.Points>=27]
# Out:
#                       Name Position                    Team  Age  Height  \
# 69             Joel Embiid        C     Philadelphia Sixers   27   7' 0"
# 113            Zach LaVine       SG           Chicago Bulls   26   6' 5"
# 171  Giannis Antetokounmpo       PF         Milwaukee Bucks   26  6' 11"
# 267           Bradley Beal       SG      Washington Wizards   28   6' 3"
# 287          Stephen Curry       PG   Golden State Warriors   33   6' 3"
# 378            Luka Doncic       PG        Dallas Mavericks   22   6' 7"
# 449        Zion Williamson       PF    New Orleans Pelicans   21   6' 7"
# 529         Damian Lillard       PG  Portland Trail Blazers   31   6' 2"
#
#      Height_i  Weight      College      Salary  Points  Rebounds  Assists
# 69       7.00     280       Kansas  31579390.0    28.5      10.6      2.8
# 113      6.50     200         UCLA  19500000.0    27.4       5.0      4.9
# 171      6.11     242          NaN  39344970.0    28.1      11.0      5.9
# 267      6.30     207      Florida  33724200.0    31.3       4.7      4.4
# 287      6.30     185     Davidson  45780966.0    32.0       5.5      5.8
# 378      6.70     230          NaN  10174391.0    27.7       8.0      8.6
# 449      6.70     284         Duke  10733400.0    27.0       7.2      3.7
# 529      6.20     195  Weber State  39344900.0    28.8       4.2      7.5

# %% [markdown]
# **&#x1F58B; A vous**
# Donner les joueurs provenant du collège du Kentuchy.

# %%
df.loc[df.College=='Kentucky']
# Out:
#                         Name Position                    Team  Age  Height  \
# 7                Enes Kanter        C          Boston Celtics   29  6' 10"
# 51             Kevin Knox II       SF         New York Knicks   22   6' 7"
# 53              Nerlens Noel        C         New York Knicks   27  6' 11"
# 57         Immanuel Quickley       SG         New York Knicks   22   6' 3"
# 58             Julius Randle       PF         New York Knicks   26   6' 8"
# 75              Tyrese Maxey       PG     Philadelphia Sixers   20   6' 2"
# 136           Hamidou Diallo       SG         Detroit Pistons   23   6' 5"
# 146               Trey Lyles       PF         Detroit Pistons   25   6' 9"
# 158           Isaiah Jackson       PF          Indiana Pacers   19  6' 10"
# 222            Nick Richards        C       Charlotte Hornets   23   7' 0"
# 227          P.J. Washington       PF       Charlotte Hornets   23   6' 7"
# 228              Bam Adebayo        C              Miami Heat   24   6' 9"
# 233              Tyler Herro       PG              Miami Heat   21   6' 5"
# 295            Mychal Mulder       SG   Golden State Warriors   27   6' 3"
# 304             Eric Bledsoe       SG    Los Angeles Clippers   31   6' 1"
# 306         DeMarcus Cousins        C    Los Angeles Clippers   31  6' 10"
# 316        Patrick Patterson       PF    Los Angeles Clippers   32   6' 8"
# 326            Anthony Davis       PF      Los Angeles Lakers   28  6' 10"
# 333               Malik Monk       SG      Los Angeles Lakers   23   6' 3"
# 335              Rajon Rondo       PG      Los Angeles Lakers   35   6' 1"
# 338             Devin Booker       SG            Phoenix Suns   24   6' 5"
# 357             De'Aaron Fox       PG        Sacremento Kings   23   6' 3"
# 377      Willie Cauley-Stein        C        Dallas Mavericks   28   7' 0"
# 408                John Wall       PG         Houston Rockets   31   6' 3"
# 434           Wenyen Gabriel       PF    New Orleans Pelicans   24   6' 9"
# 456           Keldon Johnson       SF       San Antonio Spurs   21   6' 5"
# 482             Jamal Murray       PG          Denver Nuggets   24   6' 3"
# 499       Karl-Anthony Towns        C  Minnesota Timberwolves   25  6' 11"
# 500        Jarred Vanderbilt       PF  Minnesota Timberwolves   22   6' 9"
# 508  Shai Gilgeous-Alexander       SG   Oklahoma City Thunder   23   6' 6"
#
#      Height_i  Weight   College      Salary  Points  Rebounds  Assists
# 7        6.10     250  Kentucky   1669178.0    11.2      11.0      1.2
# 51       6.70     215  Kentucky   5845979.0     3.9       1.5      0.5
# 53       6.11     220  Kentucky   8000000.0     5.1       6.4      0.7
# 57       6.30     190  Kentucky   2210640.0    11.4       2.1      2.0
# 58       6.80     250  Kentucky  21780000.0    24.1      10.2      6.0
# 75       6.20     200  Kentucky   2602920.0     8.0       1.7      2.0
# 136      6.50     202  Kentucky   5200000.0    11.6       5.2      1.9
# 146      6.90     234  Kentucky   2500000.0     5.0       3.7      0.6
# 158      6.10     205  Kentucky   2451240.0     NaN       NaN      NaN
# 222      7.00     245  Kentucky   1517981.0     0.8       0.6      0.1
# 227      6.70     230  Kentucky   4215120.0    12.9       6.5      2.5
# 228      6.90     255  Kentucky  28103500.0    18.7       9.0      5.4
# 233      6.50     195  Kentucky   4004280.0    15.1       5.0      3.4
# 295      6.30     184  Kentucky   1782621.0     5.6       1.0      0.4
# 304      6.10     214  Kentucky  18125000.0    12.2       3.4      3.8
# 306      6.10     270  Kentucky         NaN     8.9       6.4      1.9
# 316      6.80     235  Kentucky         NaN     5.2       2.0      0.8
# 326      6.10     253  Kentucky  35361360.0    21.8       7.9      3.1
# 333      6.30     200  Kentucky   1669178.0    11.7       2.4      2.1
# 335      6.10     180  Kentucky   1669178.0     5.4       2.4      4.4
# 338      6.50     206  Kentucky  31650600.0    25.6       4.2      4.3
# 357      6.30     185  Kentucky  28103550.0    25.2       3.5      7.2
# 377      7.00     240  Kentucky   4100000.0     5.3       4.5      0.7
# 408      6.30     210  Kentucky  44310840.0    20.6       3.2      6.9
# 434      6.90     205  Kentucky   1762796.0     3.4       2.6      0.5
# 456      6.50     220  Kentucky   2145720.0    12.8       6.0      1.8
# 482      6.30     215  Kentucky  29467800.0    21.2       4.0      4.8
# 499      6.11     248  Kentucky  31650600.0    24.8      10.6      4.5
# 500      6.90     214  Kentucky         NaN     5.4       5.8      1.2
# 508      6.60     180  Kentucky   5495532.0    23.7       4.7      5.9

# %% [markdown]
# ### Opération classique : Moyenne, maximum et minimum

# %% [markdown]
# &#x27A1; On peut calculer la moyenne des salaires :

# %%
df["Salary"].mean()   # ou df.Salary.mean()
# Out:
# 8813695.5752809

# %% [markdown]
# &#x27A1; le maximum

# %%
df["Salary"].max()
# Out:
# 45780966.0

# %% [markdown]
# &#x27A1; le minimum

# %%
df["Salary"].min()
# Out:
# 925258.0

# %% [markdown]
# ### Filtrer les lignes avec des indices en utilisant `iloc`
#
# &#x27A1; On peut également faire afficher le salaire max et le nom du joueur correspondant :

# %%
result = df[df["Salary"].max() == df["Salary"]]["Name"].iloc[0]
print(result)
# Out:
# Stephen Curry

# %% [markdown]
# **&#x1F58B; A vous**
# Faites de même pour faire apparaitre le nom du joueur ayant le salaire minimum.

# %% [markdown]
# **&#x1F58B; A vous**
# Faire apparaitre le poste de Kemba Walker

# %%
result = df[df["Name"] == "Kemba Walker"]["Position"].iloc[0]
print(result)

# %% [markdown]
# **&#x1F58B; A vous**
# Faire apparaitre le plus grand joueur

# %%
result = df[df["Height"].max() == df["Height"]]["Name"].iloc[0]
print(result)

# %% [markdown]
# **&#x1F58B; A vous**
# Faire apparaitre le plus petit joueur

# %%
result = df[df["Height"].min() == df["Height"]]["Name"].iloc[0]
print(result)

# %%
df.loc[df['Name']=='Jared Harper']

# %% [markdown]
# **&#x1F58B; A vous**
# Faire apparaitre le meilleur rebondeur

# %% [markdown]
# **&#x1F58B; A vous**
# Donner le nom du meilleur marqueur ainsi que sa moyenne de points

# %%
pointsmax=df["Points"].max()
result = df[df["Points"].max() == df["Points"]]["Name"].iloc[0]
print(result,pointsmax)

# %%
result = df[df["Points"].max() == df["Points"]][["Name","Points"]].iloc[0]
print(result)

# %% [markdown]
# **&#x1F58B; A vous**
# Donner les joueurs des Brooklyn Nets

# %% [markdown]
# &#x27A1;  On peut regrouper les informations selon un critère

# %%
position_mean = df.groupby(["Position"]).mean()
result = position_mean[["Salary","Age","Points"]]
result = result.round(2)
print(result)
# Out:
#                Salary    Age  Points
# Position
# C          8456428.80  26.02    9.44
# F          2560251.89  24.75    5.57
# G          8980619.71  24.93    8.62
# PF         8111010.82  25.72    8.54
# PG        11215125.14  25.74   11.04
# SF         8850135.80  25.72    9.60
# SG         8193987.70  24.99   10.23

# %% [markdown]
# **&#x1F58B; A vous**
# Regrouper les joueurs en fonction de leur age : donner Salaires, points, rebond, assist

# %%
position_mean = df.groupby(["Age"]).mean()
result = position_mean[["Salary","Points"]]
result = result.round(2)
print(result)
# Out:
#           Salary  Points
# Age
# 18    4356240.00     NaN
# 19    3491814.67    8.20
# 20    4223284.71    7.21
# 21    3406872.79    8.25
# 22    4192325.67    9.10
# 23    6774844.88    8.78
# 24    7277468.36    8.63
# 25    8694282.25    8.58
# 26   11202414.08   10.50
# 27   10732572.84   11.47
# 28    8559695.57    9.56
# 29   13234492.09   11.36
# 30   12910878.62   10.27
# 31   23352115.06   13.32
# 32   16003671.33   12.35
# 33   12974515.94   10.61
# 34    5556392.67    7.32
# 35   10663609.33   10.66
# 36   14575452.17   10.92
# 37    1669178.00    8.40
# 41    1669178.00    4.00

# %% [markdown]
# # Création de graphique

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
X = df['Weight']
Y = df['Height_i']

plt.plot(X,Y,'ro') # r pour red, o pour un cercle. voir https://matplotlib.org/api/markers_api.html
plt.show()

# %% [markdown]
# &#x27A1;  L'interprétation numérique permet à `pandas` d'analyser automatiquement les données, avec notamment la fonction `describe()`.

# %%
df['Height_i'].describe()

# %%
df.boxplot('Height_i')

# %%
df[['Name','Team']]
# Out:
#                  Name            Team
# 0      Juhann Begarin  Boston Celtics
# 1        Jaylen Brown  Boston Celtics
# 2           Kris Dunn  Boston Celtics
# 3      Carsen Edwards  Boston Celtics
# 4          Tacko Fall  Boston Celtics
# ..                ...             ...
# 553      Juwan Morgan       Utah Jazz
# 554     Royce O'Neale       Utah Jazz
# 555       Olumiye Oni       Utah Jazz
# 556     Eric Paschall       Utah Jazz
# 557  Hassan Whiteside       Utah Jazz
#
# [558 rows x 2 columns]

# %% [markdown]
# # Rajout d'une colonne
#
# &#x27A1;  Afin de pouvoir trier les joueurs suivant de nouveaux critères, nous allons rajouter un champ pour chaque joueur.
#
# Prenons un exemple stupide : fabriquons un nouveau champ `'Taille en cm'` qui contiendra la taille des joueurs aprés conversion en cm.
# Ceci se fera simplement par :

# %%
conversions = [30.48, 2.54]

df['Taille'] = df['Height_i'].str.split('-').apply(pd.Series).astype(int).dot(conversions)

# %%
df
# Out:
#                  Name Position            Team  Age  Height Height_i  Weight  \
# 0      Juhann Begarin       SG  Boston Celtics   19   6' 5"      6-5     185
# 1        Jaylen Brown       SG  Boston Celtics   24   6' 6"      6-6     223
# 2           Kris Dunn       PG  Boston Celtics   27   6' 3"      6-3     205
# 3      Carsen Edwards       PG  Boston Celtics   23  5' 11"     5-11     200
# 4          Tacko Fall        C  Boston Celtics   25   7' 5"      7-5     311
# ..                ...      ...             ...  ...     ...      ...     ...
# 553      Juwan Morgan       SF       Utah Jazz   24   6' 7"      6-7     232
# 554     Royce O'Neale       PF       Utah Jazz   28   6' 4"      6-4     226
# 555       Olumiye Oni       SG       Utah Jazz   24   6' 5"      6-5     206
# 556     Eric Paschall        F       Utah Jazz   24   6' 6"      6-6     255
# 557  Hassan Whiteside        C       Utah Jazz   32   7' 0"      7-0     265
#
#         College      Salary  Points  Rebounds  Assists  Taille
# 0           NaN         NaN     NaN       NaN      NaN  195.58
# 1    California  26758928.0    24.7       6.0      3.4  198.12
# 2    Providence   5005350.0     1.3       1.5      0.5  190.50
# 3        Purdue   1782621.0     4.0       0.8      0.5  180.34
# 4           UCF         NaN     2.5       2.7      0.2  226.06
# ..          ...         ...     ...       ...      ...     ...
# 553     Indiana         NaN     1.2       1.0      0.3  200.66
# 554      Baylor   8800000.0     7.0       6.8      2.5  193.04
# 555        Yale   1782621.0     NaN       NaN      NaN  195.58
# 556   Villanova   1782621.0     9.5       3.2      1.3  198.12
# 557    Marshall   1669178.0     8.1       6.0      0.6  213.36
#
# [558 rows x 13 columns]

# %% [markdown]
# **&#x1F58B; A vous**
# Déterminer la taille moyenne d'un joueur NBA

# %% [markdown]
# **&#x1F58B; A vous**
# Faite de même pour convertir le poid en kg.

# %%
df['Poids'] = round(df['Weight'] * 0.45359 ,0)

# %%
df
# Out:
#                  Name Position            Team  Age  Height Height_i  Weight  \
# 0      Juhann Begarin       SG  Boston Celtics   19   6' 5"      6-5     185
# 1        Jaylen Brown       SG  Boston Celtics   24   6' 6"      6-6     223
# 2           Kris Dunn       PG  Boston Celtics   27   6' 3"      6-3     205
# 3      Carsen Edwards       PG  Boston Celtics   23  5' 11"     5-11     200
# 4          Tacko Fall        C  Boston Celtics   25   7' 5"      7-5     311
# ..                ...      ...             ...  ...     ...      ...     ...
# 553      Juwan Morgan       SF       Utah Jazz   24   6' 7"      6-7     232
# 554     Royce O'Neale       PF       Utah Jazz   28   6' 4"      6-4     226
# 555       Olumiye Oni       SG       Utah Jazz   24   6' 5"      6-5     206
# 556     Eric Paschall        F       Utah Jazz   24   6' 6"      6-6     255
# 557  Hassan Whiteside        C       Utah Jazz   32   7' 0"      7-0     265
#
#         College      Salary  Points  Rebounds  Assists  Taille  total_P+A  \
# 0           NaN         NaN     NaN       NaN      NaN  195.58        0.0
# 1    California  26758928.0    24.7       6.0      3.4  198.12       28.1
# 2    Providence   5005350.0     1.3       1.5      0.5  190.50        1.8
# 3        Purdue   1782621.0     4.0       0.8      0.5  180.34        4.5
# 4           UCF         NaN     2.5       2.7      0.2  226.06        2.7
# ..          ...         ...     ...       ...      ...     ...        ...
# 553     Indiana         NaN     1.2       1.0      0.3  200.66        1.5
# 554      Baylor   8800000.0     7.0       6.8      2.5  193.04        9.5
# 555        Yale   1782621.0     NaN       NaN      NaN  195.58        0.0
# 556   Villanova   1782621.0     9.5       3.2      1.3  198.12       10.8
# 557    Marshall   1669178.0     8.1       6.0      0.6  213.36        8.7
#
#      Poids
# 0     84.0
# 1    101.0
# 2     93.0
# 3     91.0
# 4    141.0
# ..     ...
# 553  105.0
# 554  103.0
# 555   93.0
# 556  116.0
# 557  120.0
#
# [558 rows x 15 columns]

# %% [markdown]
# **&#x1F58B; A vous**
# Faire afficher la répartition des tailles (Voir plus haut)

# %%
df['Taille'].describe()
# Out:
# count    558.000000
# mean     195.573477
# std        9.346750
# min      155.000000
# 25%      188.000000
# 50%      196.000000
# 75%      201.000000
# max      226.000000
# Name: Taille, dtype: float64

# %%
df.boxplot('Taille')
# Out:
# <AxesSubplot:>

# %% [markdown]
# &#x27A1; Trier les joueurs par ordre décroissant de poids

# %%
p=df.sort_values(by=['Poids'], ascending = False)
p
# Out:
#                  Name Position                    Team  Age  Height  Height_i  \
# 4          Tacko Fall        C          Boston Celtics   25   7' 5"      7.50
# 383  Boban Marjanovic        C        Dallas Mavericks   33   7' 4"      7.40
# 534      Jusuf Nurkic        C  Portland Trail Blazers   27  6' 11"      6.11
# 480      Nikola Jokic        C          Denver Nuggets   26  6' 11"      6.11
# 449   Zion Williamson       PF    New Orleans Pelicans   21   6' 7"      6.70
# ..                ...      ...                     ...  ...     ...       ...
# 418       Tim Frazier       PG       Memphis Grizzlies   30   6' 0"      6.00
# 441    Kira Lewis Jr.       PG    New Orleans Pelicans   20   6' 1"      6.10
# 479   Nah'Shon Hyland       PG          Denver Nuggets   20   6' 3"      6.30
# 73         Isaiah Joe       SG     Philadelphia Sixers   22   6' 4"      6.40
# 389      Tyrell Terry       PG        Dallas Mavericks   20   6' 2"      6.20
#
#      Weight                College      Salary  Points  Rebounds  Assists  \
# 4       311                    UCF         NaN     2.5       2.7      0.2
# 383     290                    NaN   3500000.0     4.7       3.9      0.3
# 534     290                    NaN  12000000.0    11.5       9.0      3.4
# 480     284                    NaN  31579390.0    26.4      10.8      8.3
# 449     284                   Duke  10733400.0    27.0       7.2      3.7
# ..      ...                    ...         ...     ...       ...      ...
# 418     170             Penn State         NaN     1.6       1.6      3.2
# 441     170                Alabama   3822240.0     6.4       1.3      2.3
# 479     165  Virginia Commonwealth   2096880.0     NaN       NaN      NaN
# 73      165               Arkansas   1517981.0     3.7       0.9      0.5
# 389     160               Stanford   1517981.0     1.0       0.5      0.5
#
#      Taille  Poids
# 4     226.0  141.0
# 383   224.0  132.0
# 534   186.0  132.0
# 480   186.0  129.0
# 449   201.0  129.0
# ..      ...    ...
# 418   183.0   77.0
# 441   185.0   77.0
# 479   190.0   75.0
# 73    193.0   75.0
# 389   188.0   73.0
#
# [558 rows x 14 columns]

# %% [markdown]
# **&#x1F58B; A vous**
# Faire de même pour la taille, les scoreurs et rebondeurs

# %%
scoreur=df.sort_values(by=['Points'], ascending = False)
scoreur
# Out:
#                       Name Position                    Team  Age  Height  \
# 287          Stephen Curry       PG   Golden State Warriors   33   6' 3"
# 267           Bradley Beal       SG      Washington Wizards   28   6' 3"
# 529         Damian Lillard       PG  Portland Trail Blazers   31   6' 2"
# 69             Joel Embiid        C     Philadelphia Sixers   27   7' 0"
# 171  Giannis Antetokounmpo       PF         Milwaukee Bucks   26  6' 11"
# ..                     ...      ...                     ...  ...     ...
# 520          Aaron Wiggins       SG   Oklahoma City Thunder   22   6' 5"
# 523             Greg Brown       PF  Portland Trail Blazers   20   6' 9"
# 538        Trendon Watford        F  Portland Trail Blazers   20   6' 9"
# 543           Jared Butler       SG               Utah Jazz   21   6' 3"
# 555            Olumiye Oni       SG               Utah Jazz   24   6' 5"
#
#      Height_i  Weight      College      Salary  Points  Rebounds  Assists  \
# 287      6.30     185     Davidson  45780966.0    32.0       5.5      5.8
# 267      6.30     207      Florida  33724200.0    31.3       4.7      4.4
# 529      6.20     195  Weber State  39344900.0    28.8       4.2      7.5
# 69       7.00     280       Kansas  31579390.0    28.5      10.6      2.8
# 171      6.11     242          NaN  39344970.0    28.1      11.0      5.9
# ..        ...     ...          ...         ...     ...       ...      ...
# 520      6.50     190     Maryland         NaN     NaN       NaN      NaN
# 523      6.90     205        Texas    925258.0     NaN       NaN      NaN
# 538      6.90     240          LSU         NaN     NaN       NaN      NaN
# 543      6.30     195       Baylor    925258.0     NaN       NaN      NaN
# 555      6.50     206         Yale   1782621.0     NaN       NaN      NaN
#
#      Taille  Poids
# 287   190.0   84.0
# 267   190.0   94.0
# 529   188.0   88.0
# 69    213.0  127.0
# 171   186.0  110.0
# ..      ...    ...
# 520   196.0   86.0
# 523   206.0   93.0
# 538   206.0  109.0
# 543   190.0   88.0
# 555   196.0   93.0
#
# [558 rows x 14 columns]

# %% [markdown]
# **&#x1F58B; A vous**
#
# 1. Créer une colonne contenant l'IMC de chaque joueur
# 2. Créer une nouvelle dataframe contenant tous les joueurs du top14 classés par ordre d'IMC croissant.

# %% [markdown]
# **&#x1F58B; A vous**
# Créer une dataframe contenant les joueurs en provenance de Duke

# %%
dfduke=df[df['College']=='Duke']

# %%
dfduke
# Out:
#                    Name Position                    Team  Age  Height  \
# 11        Jabari Parker       PF          Boston Celtics   26   6' 8"
# 16         Jayson Tatum       SF          Boston Celtics   23   6' 8"
# 31         Kyrie Irving       PG           Brooklyn Nets   29   6' 2"
# 39        Jahlil Okafor        C           Brooklyn Nets   25  6' 10"
# 45           RJ Barrett       SG         New York Knicks   21   6' 6"
# 67           Seth Curry       SG     Philadelphia Sixers   31   6' 2"
# 99       Gary Trent Jr.       SG         Toronto Raptors   22   6' 5"
# 140       Frank Jackson       PG         Detroit Pistons   23   6' 3"
# 166     Cassius Stanley       SG          Indiana Pacers   22   6' 5"
# 170       Grayson Allen       SG         Milwaukee Bucks   25   6' 4"
# 179         Rodney Hood       SG         Milwaukee Bucks   28   6' 8"
# 200       Jalen Johnson       SF           Atlanta Hawks   19   6' 9"
# 203         Cam Reddish       SF           Atlanta Hawks   22   6' 8"
# 211    Vernon Carey Jr.        C       Charlotte Hornets   20   6' 9"
# 221       Mason Plumlee        C       Charlotte Hornets   31  6' 11"
# 248  Wendell Carter Jr.        C           Orlando Magic   22  6' 10"
# 312        Luke Kennard       SG    Los Angeles Clippers   25   6' 5"
# 319     Justise Winslow       PF    Los Angeles Clippers   25   6' 6"
# 354   Marvin Bagley III       PF        Sacremento Kings   22  6' 11"
# 388           JJ Redick       SG        Dallas Mavericks   37   6' 3"
# 399        Matthew Hurt        F         Houston Rockets   21   6' 9"
# 421          Tyus Jones       PG       Memphis Grizzlies   25   6' 0"
# 439      Brandon Ingram       SF    New Orleans Pelicans   24   6' 8"
# 449     Zion Williamson       PF    New Orleans Pelicans   21   6' 7"
# 457           Tre Jones       PG       San Antonio Spurs   21   6' 1"
# 485       Austin Rivers       SG          Denver Nuggets   29   6' 4"
# 526     Harry Giles III       PF  Portland Trail Blazers   23  6' 11"
#
#      Height_i  Weight College      Salary  Points  Rebounds  Assists  Taille  \
# 11       6.80     245    Duke   2283034.0     5.5       3.2      0.8   203.0
# 16       6.80     210    Duke  28103500.0    26.4       7.4      4.3   203.0
# 31       6.20     195    Duke  35328700.0    26.9       4.8      6.0   188.0
# 39       6.10     270    Duke   2130023.0     5.4       2.4      0.5   185.0
# 45       6.60     214    Duke   8623920.0    17.6       5.8      3.0   198.0
# 67       6.20     185    Duke   8207518.0    12.5       2.4      2.7   188.0
# 99       6.50     209    Duke  16000000.0    15.3       2.6      1.4   196.0
# 140      6.30     205    Duke   3000000.0     9.8       2.2      0.9   190.0
# 166      6.50     190    Duke         NaN     1.5       0.8      0.0   196.0
# 170      6.40     198    Duke   4054695.0    10.6       3.2      2.2   193.0
# 179      6.80     208    Duke   1669178.0     4.5       1.9      1.0   203.0
# 200      6.90     220    Duke   2659580.0     NaN       NaN      NaN   206.0
# 203      6.80     218    Duke   4670160.0    11.2       4.0      1.3   203.0
# 211      6.90     270    Duke   1517981.0     2.4       1.4      0.1   206.0
# 221      6.11     254    Duke   9248333.0    10.4       9.3      3.6   186.0
# 248      6.10     270    Duke   6920027.0    11.2       8.2      1.9   185.0
# 312      6.50     206    Duke  13347727.0     8.3       2.6      1.7   196.0
# 319      6.60     222    Duke   3902439.0     6.8       4.5      1.9   198.0
# 354      6.11     235    Duke  11312114.0    14.1       7.4      1.0   186.0
# 388      6.30     200    Duke         NaN     7.4       1.5      1.2   190.0
# 399      6.90     235    Duke         NaN     NaN       NaN      NaN   206.0
# 421      6.00     196    Duke   8376286.0     6.3       2.0      3.7   183.0
# 439      6.80     190    Duke  29467800.0    23.8       4.9      4.9   203.0
# 449      6.70     284    Duke  10733400.0    27.0       7.2      3.7   201.0
# 457      6.10     185    Duke   1517981.0     2.5       0.6      1.1   185.0
# 485      6.40     200    Duke   1669178.0     7.9       2.3      2.3   193.0
# 526      6.11     240    Duke         NaN     2.8       3.5      0.8   186.0
#
#      Poids
# 11   111.0
# 16    95.0
# 31    88.0
# 39   122.0
# 45    97.0
# 67    84.0
# 99    95.0
# 140   93.0
# 166   86.0
# 170   90.0
# 179   94.0
# 200  100.0
# 203   99.0
# 211  122.0
# 221  115.0
# 248  122.0
# 312   93.0
# 319  101.0
# 354  107.0
# 388   91.0
# 399  107.0
# 421   89.0
# 439   86.0
# 449  129.0
# 457   84.0
# 485   91.0
# 526  109.0

# %% [markdown]
# **&#x1F58B; A vous**
# Déterminer les joueurs gagnat plus de 15 millions de dollars et marquant moins de 10 points par match (le ET : &)

# %%
df.loc[(df.Points<10) & (df.Salary>=15000000)]
# Out:
#                   Name Position                   Team  Age  Height  Height_i  \
# 128        Ricky Rubio        G    Cleveland Cavaliers   30   6' 3"      6.30
# 255        Gary Harris       SG          Orlando Magic   26   6' 4"      6.40
# 271  Spencer Dinwiddie       PG     Washington Wizards   28   6' 5"      6.50
# 288     Draymond Green       PF  Golden State Warriors   31   6' 6"      6.60
# 411       Steven Adams        C      Memphis Grizzlies   28  6' 11"      6.11
#
#      Weight         College      Salary  Points  Rebounds  Assists  Taille  \
# 128     190             NaN  17800000.0     8.6       3.3      6.4   190.0
# 255     210  Michigan State  20482143.0     9.9       2.0      2.0   193.0
# 271     215        Colorado  17142857.0     6.7       4.3      3.0   196.0
# 288     230  Michigan State  24026712.0     7.0       7.1      8.9   198.0
# 411     265      Pittsburgh  17073171.0     7.6       8.9      1.9   186.0
#
#      Poids
# 128   86.0
# 255   95.0
# 271   98.0
# 288  104.0
# 411  120.0

# %% [markdown]
# **&#x1F58B; A vous**
# Créer une dictionnaire avec les divers colléges comme clé et le nombre de joueurs comme valeur.

# %%
dico={}
for k in df.College:
    if k not in dico:
        if k !="nan":
            dico[k]=1
    else:
        dico[k]+=1
print(dico)
# Out:
# {nan: 73, 'California': 1, 'Providence': 1, 'Purdue': 2, 'UCF': 1, 'Maryland': 6, 'Florida': 7, 'Kentucky': 30, 'Vanderbilt': 5, 'Indiana': 8, 'Duke': 27, 'Oregon': 8, 'Tennessee': 6, 'Oklahoma State': 2, 'Texas A&M': 4, 'Texas': 14, "Saint Joseph's": 4, 'Miami (FL)': 2, 'West Virginia': 2, 'Georgia': 3, 'Pepperdine': 1, 'Florida State': 11, 'Oklahoma': 3, 'Arizona State': 3, 'Virginia': 8, 'Eastern Arizona Coll. (J.C.)': 1, 'Missouri State': 1, 'Wake Forest': 7, 'Fresno State': 2, "Saint Mary's": 2, 'Louisiana Tech': 1, 'Mississippi State': 3, 'North Carolina': 13, 'LSU': 6, 'Creighton': 3, 'Colorado': 3, 'USC': 10, 'Houston': 4, 'Auburn': 5, "St. John's": 3, 'Memphis': 4, 'Dayton': 2, 'Connecticut': 5, 'Western Kentucky': 1, 'Cincinnati': 1, 'Kansas': 12, 'Michigan State': 8, 'Arkansas': 5, 'SMU': 3, 'Iowa State': 5, 'Gonzaga': 9, 'DePaul': 2, 'Charleston': 2, 'Washington': 8, 'Nebraska': 2, 'UNLV': 3, 'New Mexico JC': 1, 'Wisconsin': 2, 'San Diego State': 3, 'Baylor': 5, 'Louisville': 6, 'Arizona': 11, 'New Mexico State': 1, 'Wichita State': 2, 'George Washington': 1, 'Villanova': 9, 'UCLA': 13, 'Illinois': 2, 'Radford': 1, 'Alabama': 5, 'Penn State': 2, 'Truman State': 1, 'Kansas State': 3, 'Belmont': 1, 'Iowa': 2, 'Syracuse': 5, 'Michigan': 11, 'North Carolina State': 2, 'USC Upstate': 1, 'Butler': 3, 'Xavier': 2, 'BYU': 1, 'Notre Dame': 1, 'IUPUI': 1, 'Stanford': 7, 'Seton Hall': 1, 'Florida Gulf Coast': 1, 'Utah': 3, 'Delaware': 1, 'Nevada': 3, 'Pittsburgh': 2, 'Marquette': 5, 'TCU': 3, 'UC Santa Barbara': 3, 'Georgetown': 3, 'Rhode Island': 1, 'Long Beach State': 1, 'South Carolina': 3, 'Liberty': 1, 'David Lipscomb University': 1, 'Davidson': 1, 'Drexel': 1, 'Salt Lake CC UT': 1, 'Washington State': 2, 'Minnesota': 2, 'Boston College': 1, 'Ohio': 1, 'John A. Logan College': 1, 'Old Dominion': 1, 'North Carolina-Wilmington': 1, 'Boise State': 1, 'Murray State': 2, 'Louisiana-Lafayette': 1, 'Ole Miss': 1, 'Bowling Green': 1, 'Wyoming': 2, 'Utah State': 2, 'Texas Tech': 2, 'Vermont': 1, 'Cal Poly': 1, 'Ohio State': 4, 'Loyola (MD)': 1, 'Missouri': 3, 'Virginia Tech': 1, 'Oregon State': 1, 'Cleveland State': 1, 'Western Texas Coll. (J.C.)': 1, 'Georgia Tech': 3, 'Tulsa': 1, 'Virginia Commonwealth': 1, 'William & Mary': 1, 'Moravian': 1, 'Bucknell': 1, 'Montana State': 1, 'Tennessee State': 1, 'Weber State': 1, 'Lehigh': 1, 'New Mexico': 1, 'Yale': 1, 'Marshall': 1}

# %% [markdown]
# **&#x1F58B; A vous**
# Donner le joueur moyenne en NBA (Age, Taille, Salaire, Points, etc)

# %% [markdown]
# &#x27A1; On peut également ajouter des colonnes :

# %%
df['total_P+A'] = df[['Points','Assists']].sum(axis=1)
df_1 = df.sort_values('total_P+A',ascending=False).dropna().head(20)  #dropna() supprimme toutes les lignes avec des valeurs NULL

df_1 = df_1.drop(columns=["Height","Height_i","Weight","College","Poids"])  # on supprime certaines colonnes.
df_1
# Out:
#                         Name Position                    Team  Age  \
# 287            Stephen Curry       PG   Golden State Warriors   33
# 529           Damian Lillard       PG  Portland Trail Blazers   31
# 267             Bradley Beal       SG      Washington Wizards   28
# 29              James Harden       SG           Brooklyn Nets   32
# 206               Trae Young       PG           Atlanta Hawks   22
# 336        Russell Westbrook       PG      Los Angeles Lakers   32
# 31              Kyrie Irving       PG           Brooklyn Nets   29
# 25              Kevin Durant       PF           Brooklyn Nets   32
# 357             De'Aaron Fox       PG        Sacremento Kings   23
# 113              Zach LaVine       SG           Chicago Bulls   26
# 552         Donovan Mitchell       SG               Utah Jazz   25
# 69               Joel Embiid        C     Philadelphia Sixers   27
# 16              Jayson Tatum       SF          Boston Celtics   23
# 449          Zion Williamson       PF    New Orleans Pelicans   21
# 58             Julius Randle       PF         New York Knicks   26
# 313            Kawhi Leonard       SF    Los Angeles Clippers   30
# 338             Devin Booker       SG            Phoenix Suns   24
# 508  Shai Gilgeous-Alexander       SG   Oklahoma City Thunder   23
# 499       Karl-Anthony Towns        C  Minnesota Timberwolves   25
# 129            Collin Sexton       PG     Cleveland Cavaliers   22
#
#          Salary  Points  Rebounds  Assists  Taille  total_P+A
# 287  45780966.0    32.0       5.5      5.8  190.50       37.8
# 529  39344900.0    28.8       4.2      7.5  187.96       36.3
# 267  33724200.0    31.3       4.7      4.4  190.50       35.7
# 29   44310840.0    24.6       7.9     10.8  195.58       35.4
# 206   8326471.0    25.3       3.9      9.4  185.42       34.7
# 336  44211146.0    22.2      11.5     11.7  190.50       33.9
# 31   35328700.0    26.9       4.8      6.0  187.96       32.9
# 25   42018900.0    26.9       7.1      5.6  185.42       32.5
# 357  28103550.0    25.2       3.5      7.2  190.50       32.4
# 113  19500000.0    27.4       5.0      4.9  195.58       32.3
# 552  28103500.0    26.4       4.4      5.2  185.42       31.6
# 69   31579390.0    28.5      10.6      2.8  213.36       31.3
# 16   28103500.0    26.4       7.4      4.3  203.20       30.7
# 449  10733400.0    27.0       7.2      3.7  200.66       30.7
# 58   21780000.0    24.1      10.2      6.0  203.20       30.1
# 313  36016200.0    24.8       6.5      5.2  200.66       30.0
# 338  31650600.0    25.6       4.2      4.3  195.58       29.9
# 508   5495532.0    23.7       4.7      5.9  198.12       29.6
# 499  31650600.0    24.8      10.6      4.5  210.82       29.3
# 129   6439671.0    24.3       3.1      4.4  185.42       28.7

# %% [markdown]
# **&#x1F58B; A vous**
# Faire de même mais en rajoutant les rebonds, classer les 20 premiers joueurs NBA

# %%
df['total_P+A'] = df[['Points','Assists']].sum(axis=1)
df_1 = df.sort_values('total_P+A',ascending=False).dropna().head(20)  #dropna() supprimme toutes les lignes avec des valeurs NULL

df_1 = df_1.drop(columns=["Height","Height_i","Weight","College","Poids"])  # on supprime certaines colonnes.

df_2['total_P+A+R'] = df[['total_P+A','Rebounds']].sum(axis=1)
df_2
# Out:
#                         Name                    Team  Age  Points  Rebounds  \
# 336        Russell Westbrook      Los Angeles Lakers   32    22.2      11.5
# 29              James Harden           Brooklyn Nets   32    24.6       7.9
# 287            Stephen Curry   Golden State Warriors   33    32.0       5.5
# 69               Joel Embiid     Philadelphia Sixers   27    28.5      10.6
# 529           Damian Lillard  Portland Trail Blazers   31    28.8       4.2
# 267             Bradley Beal      Washington Wizards   28    31.3       4.7
# 58             Julius Randle         New York Knicks   26    24.1      10.2
# 499       Karl-Anthony Towns  Minnesota Timberwolves   25    24.8      10.6
# 25              Kevin Durant           Brooklyn Nets   32    26.9       7.1
# 206               Trae Young           Atlanta Hawks   22    25.3       3.9
# 16              Jayson Tatum          Boston Celtics   23    26.4       7.4
# 449          Zion Williamson    New Orleans Pelicans   21    27.0       7.2
# 31              Kyrie Irving           Brooklyn Nets   29    26.9       4.8
# 113              Zach LaVine           Chicago Bulls   26    27.4       5.0
# 313            Kawhi Leonard    Los Angeles Clippers   30    24.8       6.5
# 552         Donovan Mitchell               Utah Jazz   25    26.4       4.4
# 357             De'Aaron Fox        Sacremento Kings   23    25.2       3.5
# 508  Shai Gilgeous-Alexander   Oklahoma City Thunder   23    23.7       4.7
# 338             Devin Booker            Phoenix Suns   24    25.6       4.2
# 129            Collin Sexton     Cleveland Cavaliers   22    24.3       3.1
#
#      Assists  Taille  total_P+A  total_P+A+R
# 336     11.7  190.50       33.9         45.4
# 29      10.8  195.58       35.4         43.3
# 287      5.8  190.50       37.8         43.3
# 69       2.8  213.36       31.3         41.9
# 529      7.5  187.96       36.3         40.5
# 267      4.4  190.50       35.7         40.4
# 58       6.0  203.20       30.1         40.3
# 499      4.5  210.82       29.3         39.9
# 25       5.6  185.42       32.5         39.6
# 206      9.4  185.42       34.7         38.6
# 16       4.3  203.20       30.7         38.1
# 449      3.7  200.66       30.7         37.9
# 31       6.0  187.96       32.9         37.7
# 113      4.9  195.58       32.3         37.3
# 313      5.2  200.66       30.0         36.5
# 552      5.2  185.42       31.6         36.0
# 357      7.2  190.50       32.4         35.9
# 508      5.9  198.12       29.6         34.3
# 338      4.3  195.58       29.9         34.1
# 129      4.4  185.42       28.7         31.8
