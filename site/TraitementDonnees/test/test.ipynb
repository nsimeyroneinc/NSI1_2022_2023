# %% [markdown]
# # Trier des données

# %% [markdown]
# Nous reprenons notre fichier de joueurs de rugby du Top14.

# %%
import csv
f = open('data/Top14.csv', "r", encoding = 'utf-8')
donnees = csv.DictReader(f)
joueurs = []
for ligne in donnees:
    joueurs.append(dict(ligne))
    
f.close()

# %% [markdown]
# ### Créer une fonction filtre
# L'objectif est de créer une fonction `joueursEquipe(equipe)` qui renvoie une liste contentant tous les joueurs de l'équipe `equipe`.
# Le paramètre `equipe` sera donnée sous forme de chaîne de caractères.
# La valeur renvoyée sera de type liste.

# %%
def joueursEquipe(equipe):
    ret = []
    
    for k in joueurs :
        if k['Club'] == equipe :
            ret.append(k)
    
    return ret

# %% [markdown]
# Exemple d'utilisation :

# %%
len(joueursEquipe("Bordeaux"))
# Out:
# 43

# %% [markdown]
# Définir de la même manière une fonction `joueursPoste(poste)`.

# %% [markdown]
# ## Utilisation d'une fonction de tri

# %% [markdown]
# Comment classer les joueurs suivant leur taille ?
# La fonction `sorted(liste)` est efficace sur les listes : elle renvoie une nouvelle liste triée dans l'ordre croissant.

# %%
mylist = [4,2,8,6]
mynewlist = sorted(mylist)
print(mynewlist)
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# Mais comment trier un dictionnaire ?

# %%
test = sorted(joueurs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-de081d14a3da> in <module>
# ----> 1 test = sorted(joueurs)
#
# TypeError: '<' not supported between instances of 'dict' and 'dict'

# %% [markdown]
# Il est normal que cette tentative échoue : un dictionnaire possède plusieurs clés différentes.
# Ici, plusieurs clés peuvent être des critères de tri : la taille, le poids.

# %% [markdown]
# ### un exemple de tri de dictionnaire

# %%
Simpsons = [{"Prenom" : "Bart", "age estimé": "10"},
           {"Prenom" : "Lisa", "age estimé": "8"},
           {"Prenom" : "Maggie", "age estimé": "1"},
           {"Prenom" : "Homer", "age estimé": "38"},
           {"Prenom" : "Marge", "age estimé": "37"}]

# %%
def age(personnage):
    return int(personnage["age estimé"])

# %%
age(Simpsons[0])
# Out:
# 10

# %% [markdown]
# La création de cette fonction `age()` va nous permettre de spécifier une clé de tri, par le paramètre `key` :

# %%
triSimpsons = sorted(Simpsons, key = age)

# %%
triSimpsons
# Out:
# [{'Prenom': 'Maggie', 'age estimé': '1'},
#  {'Prenom': 'Lisa', 'age estimé': '8'},
#  {'Prenom': 'Bart', 'age estimé': '10'},
#  {'Prenom': 'Marge', 'age estimé': '37'},
#  {'Prenom': 'Homer', 'age estimé': '38'}]

# %%
triSimpsons = sorted(Simpsons, key = age, reverse = True)

# %%
triSimpsons
# Out:
# [{'Prenom': 'Homer', 'age estimé': '38'},
#  {'Prenom': 'Marge', 'age estimé': '37'},
#  {'Prenom': 'Bart', 'age estimé': '10'},
#  {'Prenom': 'Lisa', 'age estimé': '8'},
#  {'Prenom': 'Maggie', 'age estimé': '1'}]

# %% [markdown]
# ## Exercice
# 1. Trier les joueurs du top14 par taille.
# 2. Trier les joueurs de Bordeaux par taille.
# 3. Trier les joueurs de Bordeaux suivant leur Indice de Masse Corporelle ([IMC](https://fr.wikipedia.org/wiki/Indice_de_masse_corporelle) )

# %%
def taillePlayer(player) :
    return int(player['Taille'])

# %%
joueurs_taille_croissant = sorted(joueurs, key = taillePlayer)
print(joueurs_taille_croissant)

# %%
def IMC(player):
    masse = int(player['Poids'])
    taille_m = int(player['Taille']) / 100
    return masse / taille_m**2

# %%
IMC(joueurs[0])
# Out:
# 36.42987249544626

# %%
joueursUBB = [k for k in joueurs if k['Equipe'] == 'Bordeaux']

# %%
joueursUBB_tri = sorted(joueursUBB, key = IMC)

# %%
for k in joueursUBB_tri:
    print(k['Nom'], IMC(k))
# Out:
# Yann LESGOURGUES 23.450918219051392
# Nicolas PLAZY 24.049343594386603
# Matthieu JALIBERT 24.382716049382715
# Blair CONNOR 24.48565200513601
# Geoffrey CROS 24.835646457268076
# Maxime LUCU 25.2162533116282
# Jean-Baptiste DUBIÉ 25.94548395958609
# Romain BUROS 26.023048986244955
# Santiago CORDERO 26.493025631204315
# Alexandre ROUMAT 26.527905315784103
# Cameron WOKI 26.81174510620575
# Lucas MÉRET 26.82742078020452
# Nans DUCUING 27.471688898385274
# Ulupano SEUTENI 27.757487216946675
# Clément MAYNADIER 28.59675712774171
# Cyril CAZEAUX 28.823589429650035
# Alexandre FLANQUART 28.835063437139564
# Semi RADRADRA 28.85921231326392
# Scott HIGGINBOTHAM 28.928336620644316
# Ben BOTICA 29.352354500694357
# Béka GORGADZE 29.394473838918284
# Mahamadou DIABY 29.708012675418743
# Masalosalo TUTAIA 30.036524413687044
# Jandré MARAIS 30.09896949290889
# Kane DOUGLAS 30.144103519262817
# Seta TAMANIVALU 30.794210688390585
# Rémi LAMERAT 31.01370510396975
# Marco TAULEIGNE 31.523258682601902
# Afa AMOSA 32.028367983070716
# Laurent DELBOULBÈS 32.35554470254266
# Adrien PÉLISSIÉ 33.576508653582
# Lasha TABIDZE 34.18553688823959
# Lekso KAULASHVILI 34.31610855329005
# Peni RAVAI 34.76990504017531
# Jefferson POIROT 35.713195567900854
# Vadim COBILAS 36.41975308641975
# Thierry PAÏVA 36.92107750472589

# %% [markdown]
# ## Recherche des joueurs de profil  physique similaire

# %% [markdown]
# ### Distance entre deux joueurs
# Construire une fonction `distance(joueur1,joueur2)` qui renvoie la somme des carrés des différences de tailles et de poids entre les joueurs `joueur1` et `joueur2` :
# $$ d = (p_1-p_2)^2 + (t_1-t_2)^2$$

# %%
def distance(joueur1,joueur2):
    p1 = int(joueur1['Poids'])
    p2 = int(joueur2['Poids'])
    t1 = int(joueur1['Taille'])
    t2 = int(joueur2['Taille'])
    return (p1-p2)**2+(t1-t2)**2

# %% [markdown]
# ### Distance des joueurs avec Baptiste Serin

# %% [markdown]
# Retrouvons d'abord le numéro de Baptiste Serin dans notre classement de joueurs :

# %%
for k in range(len(joueurs)) :
    if joueurs[k]['Nom'] == 'SERIN Baptiste' :
        print(k)
# Out:
# 89

# %%
joueurs[89]
# Out:
# {'ID': '1380',
#  'Nom': 'SERIN Baptiste',
#  'Âge': '27',
#  'Taille': '180',
#  'Poids': '79',
#  'Nationalité': 'France',
#  'Poste': 'Mêlée',
#  'Matchs': '5',
#  'E': '2',
#  'T': '',
#  'P': '',
#  'D': '',
#  'J': '',
#  'R': '',
#  'Temps': '372',
#  'Club': 'Toulon'}

# %% [markdown]
# Nous pouvons maintenant classer les joueurs suivant leur distance morphologique à Baptiste  SERIN :

# %%
def distanceSerin(joueur2):
    return distance(joueurs[89],joueur2)

# %%
distanceSerin(joueurs[89])
# Out:
# 0

# %%
joueurs_VS_Serin = sorted(joueurs, key = distanceSerin)

# %%
joueurs_VS_Serin
# Out:
# [{'ID': '1380',
#   'Nom': 'SERIN Baptiste',
#   'Âge': '27',
#   'Taille': '180',
#   'Poids': '79',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '5',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '372',
#   'Club': 'Toulon'},
#  {'ID': '4660',
#   'Nom': 'TEDDER Tristan',
#   'Âge': '25',
#   'Taille': '180',
#   'Poids': '80',
#   'Nationalité': 'Afrique du sud',
#   'Poste': 'Ouverture',
#   'Matchs': '14',
#   'E': '2',
#   'T': '10',
#   'P': '11',
#   'D': '2',
#   'J': '',
#   'R': '',
#   'Temps': '1019',
#   'Club': 'Perpignan'},
#  {'ID': '7805',
#   'Nom': 'JAMINET Melvyn',
#   'Âge': '22',
#   'Taille': '180',
#   'Poids': '80',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '9',
#   'E': '',
#   'T': '10',
#   'P': '28',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '719',
#   'Club': 'Perpignan'},
#  {'ID': '6046',
#   'Nom': 'LUC Aymeric',
#   'Âge': '24',
#   'Taille': '180',
#   'Poids': '81',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '14',
#   'E': '3',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '1094',
#   'Club': 'Toulon'},
#  {'ID': '7657',
#   'Nom': 'AURREKOETXEA Kerman',
#   'Âge': '21',
#   'Taille': '178',
#   'Poids': '79',
#   'Nationalité': 'Espagne',
#   'Poste': 'Mêlée',
#   'Matchs': '2',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '160',
#   'Club': 'Biarritz'},
#  {'ID': '10021',
#   'Nom': 'JAUNEAU Baptiste',
#   'Âge': '18',
#   'Taille': '178',
#   'Poids': '81',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '10',
#   'Club': 'Clermont'},
#  {'ID': '2453',
#   'Nom': 'LUCU Maxime',
#   'Âge': '29',
#   'Taille': '177',
#   'Poids': '79',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '12',
#   'E': '',
#   'T': '4',
#   'P': '7',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '629',
#   'Club': 'Bordeaux'},
#  {'ID': '7212',
#   'Nom': 'ABZHANDADZE Tedo',
#   'Âge': '22',
#   'Taille': '177',
#   'Poids': '80',
#   'Nationalité': 'Géorgie',
#   'Poste': 'Ouverture',
#   'Matchs': '6',
#   'E': '',
#   'T': '1',
#   'P': '5',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '272',
#   'Club': 'Brive'},
#  {'ID': '8406',
#   'Nom': 'CAROL Thomas',
#   'Âge': '21',
#   'Taille': '179',
#   'Poids': '82',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '3',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '128',
#   'Club': 'Pau'},
#  {'ID': '3861',
#   'Nom': 'CUBELLI Tomás',
#   'Âge': '32',
#   'Taille': '177',
#   'Poids': '81',
#   'Nationalité': 'Argentine',
#   'Poste': 'Mêlée',
#   'Matchs': '9',
#   'E': '4',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '443',
#   'Club': 'Biarritz'},
#  {'ID': '6730',
#   'Nom': 'SHORT Mitch',
#   'Âge': '26',
#   'Taille': '178',
#   'Poids': '82',
#   'Nationalité': 'Australie',
#   'Poste': 'Mêlée',
#   'Matchs': '4',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '71',
#   'Club': 'Racing 92'},
#  {'ID': '10004',
#   'Nom': 'SÉGUÉLA Nino',
#   'Âge': '20',
#   'Taille': '177',
#   'Poids': '81',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '79',
#   'Club': 'Perpignan'},
#  {'ID': '811',
#   'Nom': 'PARRA Morgan',
#   'Âge': '33',
#   'Taille': '180',
#   'Poids': '83',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '8',
#   'E': '',
#   'T': '8',
#   'P': '19',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '501',
#   'Club': 'Clermont'},
#  {'ID': '8929',
#   'Nom': 'MICHET Gabin',
#   'Âge': '20',
#   'Taille': '180',
#   'Poids': '83',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '6',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '1',
#   'J': '',
#   'R': '',
#   'Temps': '183',
#   'Club': 'Clermont'},
#  {'ID': '11774',
#   'Nom': 'BIELLE-BIARREY Louis',
#   'Âge': '18',
#   'Taille': '184',
#   'Poids': '79',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '3',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '154',
#   'Club': 'Bordeaux'},
#  {'ID': '1046',
#   'Nom': 'LESGOURGUES Yann',
#   'Âge': '31',
#   'Taille': '177',
#   'Poids': '82',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '16',
#   'E': '3',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '651',
#   'Club': 'Bordeaux'},
#  {'ID': '5165',
#   'Nom': 'GIBERT Antoine',
#   'Âge': '24',
#   'Taille': '177',
#   'Poids': '76',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '16',
#   'E': '1',
#   'T': '9',
#   'P': '8',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '697',
#   'Club': 'Racing 92'},
#  {'ID': '11604',
#   'Nom': 'EYMERI Aubin',
#   'Âge': '19',
#   'Taille': '183',
#   'Poids': '82',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '4',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '27',
#   'Club': 'Montpellier'},
#  {'ID': '4422',
#   'Nom': 'COVILLE Arthur',
#   'Âge': '24',
#   'Taille': '178',
#   'Poids': '83',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '17',
#   'E': '2',
#   'T': '2',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '730',
#   'Club': 'Paris'},
#  {'ID': '6149',
#   'Nom': 'DELGUY Bautista',
#   'Âge': '24',
#   'Taille': '182',
#   'Poids': '83',
#   'Nationalité': 'Argentine',
#   'Poste': 'Ailier',
#   'Matchs': '6',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '404',
#   'Club': 'Perpignan'},
#  {'ID': '7968',
#   'Nom': 'COUILLOUD Barnabé',
#   'Âge': '23',
#   'Taille': '178',
#   'Poids': '83',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '14',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '656',
#   'Club': 'Biarritz'},
#  {'ID': '1355',
#   'Nom': 'DULIN Brice',
#   'Âge': '31',
#   'Taille': '176',
#   'Poids': '82',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '11',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '794',
#   'Club': 'La Rochelle'},
#  {'ID': '1515',
#   'Nom': 'DAUBAGNA Thibault',
#   'Âge': '27',
#   'Taille': '177',
#   'Poids': '83',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '11',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '351',
#   'Club': 'Pau'},
#  {'ID': '3863',
#   'Nom': 'CORDERO Santiago',
#   'Âge': '28',
#   'Taille': '177',
#   'Poids': '83',
#   'Nationalité': 'Argentine',
#   'Poste': 'Ailier',
#   'Matchs': '8',
#   'E': '4',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '640',
#   'Club': 'Bordeaux'},
#  {'ID': '7277',
#   'Nom': 'MORETTI Simon',
#   'Âge': '21',
#   'Taille': '180',
#   'Poids': '84',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '80',
#   'Club': 'Toulon'},
#  {'ID': '7683',
#   'Nom': 'DANOVARO Tom',
#   'Âge': '20',
#   'Taille': '180',
#   'Poids': '84',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '18',
#   'Club': 'Brive'},
#  {'ID': '7725',
#   'Nom': 'PERCILLIER Will',
#   'Âge': '23',
#   'Taille': '180',
#   'Poids': '84',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '20',
#   'Club': 'Paris'},
#  {'ID': '10350',
#   'Nom': 'DOAN Martin',
#   'Âge': '23',
#   'Taille': '176',
#   'Poids': '76',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '5',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '331',
#   'Club': 'Montpellier'},
#  {'ID': '1218',
#   'Nom': 'PÉLISSIÉ Jonathan',
#   'Âge': '33',
#   'Taille': '179',
#   'Poids': '84',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '14',
#   'E': '',
#   'T': '1',
#   'P': '1',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '654',
#   'Club': 'Lyon'},
#  {'ID': '1296',
#   'Nom': 'HART James',
#   'Âge': '30',
#   'Taille': '179',
#   'Poids': '84',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '4',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '37',
#   'Club': 'Biarritz'},
#  {'ID': '7984',
#   'Nom': 'TAOFIFENUA Donovan',
#   'Âge': '22',
#   'Taille': '179',
#   'Poids': '84',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '14',
#   'E': '3',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '1036',
#   'Club': 'Racing 92'},
#  {'ID': '3528',
#   'Nom': 'BLANC Julien',
#   'Âge': '29',
#   'Taille': '175',
#   'Poids': '81',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '11',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '522',
#   'Club': 'Toulon'},
#  {'ID': '3564',
#   'Nom': 'SANGA Enzo',
#   'Âge': '26',
#   'Taille': '176',
#   'Poids': '75',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '7',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '193',
#   'Club': 'Brive'},
#  {'ID': '3734',
#   'Nom': 'LOBZHANIDZE Vasil',
#   'Âge': '25',
#   'Taille': '175',
#   'Poids': '76',
#   'Nationalité': 'Géorgie',
#   'Poste': 'Mêlée',
#   'Matchs': '12',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '527',
#   'Club': 'Brive'},
#  {'ID': '3860',
#   'Nom': 'LANDAJO Martín',
#   'Âge': '33',
#   'Taille': '175',
#   'Poids': '82',
#   'Nationalité': 'Argentine',
#   'Poste': 'Mêlée',
#   'Matchs': '6',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '223',
#   'Club': 'Perpignan'},
#  {'ID': '1466',
#   'Nom': 'RATTEZ Vincent',
#   'Âge': '29',
#   'Taille': '180',
#   'Poids': '85',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '13',
#   'E': '3',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '921',
#   'Club': 'Montpellier'},
#  {'ID': '5910',
#   'Nom': 'DUGUIVALU Alivereti',
#   'Âge': '24',
#   'Taille': '180',
#   'Poids': '85',
#   'Nationalité': 'Fidji',
#   'Poste': 'Centre',
#   'Matchs': '12',
#   'E': '3',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '741',
#   'Club': 'Perpignan'},
#  {'ID': '9321',
#   'Nom': 'GARCIA Matéo',
#   'Âge': '19',
#   'Taille': '174',
#   'Poids': '79',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '4',
#   'E': '',
#   'T': '1',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '31',
#   'Club': 'Bordeaux'},
#  {'ID': '1091',
#   'Nom': 'BÉZY Sébastien',
#   'Âge': '30',
#   'Taille': '174',
#   'Poids': '78',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '11',
#   'E': '',
#   'T': '2',
#   'P': '2',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '653',
#   'Club': 'Clermont'},
#  {'ID': '1646',
#   'Nom': 'BALÈS Alexi',
#   'Âge': '31',
#   'Taille': '174',
#   'Poids': '80',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '11',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '291',
#   'Club': 'Toulouse'},
#  {'ID': '6080',
#   'Nom': 'VIALLARD Kévin',
#   'Âge': '21',
#   'Taille': '174',
#   'Poids': '78',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '12',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '116',
#   'Club': 'Clermont'},
#  {'ID': '7245',
#   'Nom': 'ARATA Santiago',
#   'Âge': '25',
#   'Taille': '174',
#   'Poids': '78',
#   'Nationalité': 'Uruguay',
#   'Poste': 'Mêlée',
#   'Matchs': '10',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '398',
#   'Club': 'Castres'},
#  {'ID': '9051',
#   'Nom': 'DEBAËS Thibault',
#   'Âge': '20',
#   'Taille': '179',
#   'Poids': '85',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '5',
#   'E': '1',
#   'T': '2',
#   'P': '1',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '235',
#   'Club': 'Pau'},
#  {'ID': '8266',
#   'Nom': 'HULLEU Nathanaël',
#   'Âge': '21',
#   'Taille': '178',
#   'Poids': '85',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '2',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '160',
#   'Club': 'Bordeaux'},
#  {'ID': '11023',
#   'Nom': 'PLANA Baptiste',
#   'Âge': '22',
#   'Taille': '182',
#   'Poids': '85',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '71',
#   'Club': 'Perpignan'},
#  {'ID': '1895',
#   'Nom': 'DARBO Clément',
#   'Âge': '36',
#   'Taille': '175',
#   'Poids': '75',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '64',
#   'Club': 'Biarritz'},
#  {'ID': '4362',
#   'Nom': 'COUILLOUD Baptiste',
#   'Âge': '24',
#   'Taille': '176',
#   'Poids': '84',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '8',
#   'E': '7',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '420',
#   'Club': 'Lyon'},
#  {'ID': '5464',
#   'Nom': 'APRASIDZE Gela',
#   'Âge': '24',
#   'Taille': '175',
#   'Poids': '75',
#   'Nationalité': 'Géorgie',
#   'Poste': 'Mêlée',
#   'Matchs': '6',
#   'E': '2',
#   'T': '',
#   'P': '1',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '214',
#   'Club': 'Montpellier'},
#  {'ID': '8930',
#   'Nom': 'LE GARREC Nolann',
#   'Âge': '19',
#   'Taille': '175',
#   'Poids': '75',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '10',
#   'E': '2',
#   'T': '5',
#   'P': '9',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '426',
#   'Club': 'Racing 92'},
#  {'ID': '1920',
#   'Nom': 'SANCHEZ Nicolas',
#   'Âge': '33',
#   'Taille': '177',
#   'Poids': '85',
#   'Nationalité': 'Argentine',
#   'Poste': 'Ouverture',
#   'Matchs': '3',
#   'E': '',
#   'T': '2',
#   'P': '7',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '135',
#   'Club': 'Paris'},
#  {'ID': '2464',
#   'Nom': 'POURAILLY Bastien',
#   'Âge': '28',
#   'Taille': '177',
#   'Poids': '85',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '3',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '191',
#   'Club': 'Clermont'},
#  {'ID': '3496',
#   'Nom': 'BELLEAU Anthony',
#   'Âge': '25',
#   'Taille': '177',
#   'Poids': '85',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '14',
#   'E': '1',
#   'T': '6',
#   'P': '15',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '591',
#   'Club': 'Toulon'},
#  {'ID': '7571',
#   'Nom': 'GERMAIN Baptiste',
#   'Âge': '21',
#   'Taille': '174',
#   'Poids': '82',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '7',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '383',
#   'Club': 'Toulouse'},
#  {'ID': '4448',
#   'Nom': 'HASTOY Antoine',
#   'Âge': '24',
#   'Taille': '180',
#   'Poids': '86',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '14',
#   'E': '4',
#   'T': '15',
#   'P': '31',
#   'D': '2',
#   'J': '',
#   'R': '',
#   'Temps': '995',
#   'Club': 'Pau'},
#  {'ID': '1273',
#   'Nom': 'ECOCHARD Tom',
#   'Âge': '29',
#   'Taille': '173',
#   'Poids': '80',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '9',
#   'E': '',
#   'T': '',
#   'P': '1',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '415',
#   'Club': 'Perpignan'},
#  {'ID': '1616',
#   'Nom': 'DUBIÉ Jean-Baptiste',
#   'Âge': '32',
#   'Taille': '181',
#   'Poids': '86',
#   'Nationalité': 'France',
#   'Poste': 'Centre',
#   'Matchs': '11',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '552',
#   'Club': 'Bordeaux'},
#  {'ID': '5291',
#   'Nom': "N'GANDEBE Gabriel",
#   'Âge': '24',
#   'Taille': '174',
#   'Poids': '75',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '6',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '356',
#   'Club': 'Montpellier'},
#  {'ID': '1068',
#   'Nom': 'URDAPILLETA Benjamin',
#   'Âge': '35',
#   'Taille': '178',
#   'Poids': '86',
#   'Nationalité': 'Argentine',
#   'Poste': 'Ouverture',
#   'Matchs': '12',
#   'E': '1',
#   'T': '21',
#   'P': '19',
#   'D': '1',
#   'J': '1',
#   'R': '',
#   'Temps': '871',
#   'Club': 'Castres'},
#  {'ID': '1092',
#   'Nom': 'BARRAQUE Jean-Pascal',
#   'Âge': '30',
#   'Taille': '182',
#   'Poids': '86',
#   'Nationalité': 'France',
#   'Poste': 'Centre',
#   'Matchs': '9',
#   'E': '1',
#   'T': '',
#   'P': '1',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '711',
#   'Club': 'Clermont'},
#  {'ID': '1099',
#   'Nom': "O'CONNOR Marvin",
#   'Âge': '30',
#   'Taille': '178',
#   'Poids': '86',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '10',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '670',
#   'Club': 'Clermont'},
#  {'ID': '3612',
#   'Nom': 'LAVEAU Martin',
#   'Âge': '25',
#   'Taille': '182',
#   'Poids': '86',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '7',
#   'E': '3',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '469',
#   'Club': 'Castres'},
#  {'ID': '4723',
#   'Nom': 'BOUTHIER Anthony',
#   'Âge': '29',
#   'Taille': '182',
#   'Poids': '86',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '13',
#   'E': '2',
#   'T': '1',
#   'P': '1',
#   'D': '1',
#   'J': '',
#   'R': '',
#   'Temps': '981',
#   'Club': 'Montpellier'},
#  {'ID': '3990',
#   'Nom': 'DUPICHOT Louis',
#   'Âge': '26',
#   'Taille': '183',
#   'Poids': '86',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '6',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '294',
#   'Club': 'Racing 92'},
#  {'ID': '4390',
#   'Nom': 'TISSERON Julien',
#   'Âge': '26',
#   'Taille': '183',
#   'Poids': '86',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '12',
#   'E': '3',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '711',
#   'Club': 'Montpellier'},
#  {'ID': '6578',
#   'Nom': 'BARRETT Eoghan',
#   'Âge': '22',
#   'Taille': '183',
#   'Poids': '86',
#   'Nationalité': 'Irlande',
#   'Poste': 'Ailier',
#   'Matchs': '4',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '228',
#   'Club': 'Pau'},
#  {'ID': '4337',
#   'Nom': 'CROS Geoffrey',
#   'Âge': '24',
#   'Taille': '185',
#   'Poids': '85',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '3',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '1',
#   'Temps': '169',
#   'Club': 'Bordeaux'},
#  {'ID': '5622',
#   'Nom': 'REINACH Cobus',
#   'Âge': '32',
#   'Taille': '175',
#   'Poids': '85',
#   'Nationalité': 'Afrique du sud',
#   'Poste': 'Mêlée',
#   'Matchs': '9',
#   'E': '7',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '584',
#   'Club': 'Montpellier'},
#  {'ID': '5880',
#   'Nom': 'WEST Ihaia',
#   'Âge': '30',
#   'Taille': '175',
#   'Poids': '85',
#   'Nationalité': 'Nouvelle-Zélande',
#   'Poste': 'Ouverture',
#   'Matchs': '9',
#   'E': '3',
#   'T': '19',
#   'P': '21',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '692',
#   'Club': 'La Rochelle'},
#  {'ID': '8287',
#   'Nom': 'ÉPÉE Nelson',
#   'Âge': '21',
#   'Taille': '174',
#   'Poids': '74',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '80',
#   'Club': 'Toulouse'},
#  {'ID': '3527',
#   'Nom': 'RETIÈRE Arthur',
#   'Âge': '24',
#   'Taille': '173',
#   'Poids': '75',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '5',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '319',
#   'Club': 'La Rochelle'},
#  {'ID': '4497',
#   'Nom': 'POPELIN Pierre',
#   'Âge': '26',
#   'Taille': '181',
#   'Poids': '87',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '13',
#   'E': '',
#   'T': '8',
#   'P': '7',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '551',
#   'Club': 'La Rochelle'},
#  {'ID': '5167',
#   'Nom': 'JALIBERT Matthieu',
#   'Âge': '23',
#   'Taille': '184',
#   'Poids': '86',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '10',
#   'E': '3',
#   'T': '17',
#   'P': '18',
#   'D': '',
#   'J': '2',
#   'R': '',
#   'Temps': '548',
#   'Club': 'Bordeaux'},
#  {'ID': '5362',
#   'Nom': 'LAPORTE Clément',
#   'Âge': '24',
#   'Taille': '181',
#   'Poids': '87',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '10',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '517',
#   'Club': 'Lyon'},
#  {'ID': '5558',
#   'Nom': 'FERNANDEZ Jérémy',
#   'Âge': '24',
#   'Taille': '176',
#   'Poids': '86',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '13',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '484',
#   'Club': 'Castres'},
#  {'ID': '7727',
#   'Nom': 'SPRING Max',
#   'Âge': '20',
#   'Taille': '173',
#   'Poids': '75',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '5',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '385',
#   'Club': 'Racing 92'},
#  {'ID': '1277',
#   'Nom': 'ARTRU Yohann',
#   'Âge': '29',
#   'Taille': '178',
#   'Poids': '87',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '4',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '255',
#   'Club': 'Biarritz'},
#  {'ID': '1435',
#   'Nom': 'BOSCH Gilles',
#   'Âge': '31',
#   'Taille': '178',
#   'Poids': '87',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '10',
#   'E': '',
#   'T': '5',
#   'P': '2',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '299',
#   'Club': 'Biarritz'},
#  {'ID': '1455',
#   'Nom': 'ARNOLD Toby',
#   'Âge': '34',
#   'Taille': '178',
#   'Poids': '87',
#   'Nationalité': 'Nouvelle-Zélande',
#   'Poste': 'Arrière',
#   'Matchs': '14',
#   'E': '3',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '1039',
#   'Club': 'Lyon'},
#  {'ID': '2182',
#   'Nom': 'RAMOS Thomas',
#   'Âge': '26',
#   'Taille': '178',
#   'Poids': '87',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '9',
#   'E': '2',
#   'T': '18',
#   'P': '24',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '720',
#   'Club': 'Toulouse'},
#  {'ID': '2558',
#   'Nom': 'DUPONT Antoine',
#   'Âge': '25',
#   'Taille': '174',
#   'Poids': '85',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '10',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '620',
#   'Club': 'Toulouse'},
#  {'ID': '11004',
#   'Nom': 'MAÏAU Jonathan',
#   'Âge': '20',
#   'Taille': '174',
#   'Poids': '85',
#   'Nationalité': 'France',
#   'Poste': 'Talonneur',
#   'Matchs': '4',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '37',
#   'Club': 'Racing 92'},
#  {'ID': '1609',
#   'Nom': 'LUCU Ximun',
#   'Âge': '32',
#   'Taille': '183',
#   'Poids': '87',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '80',
#   'Club': 'Biarritz'},
#  {'ID': '2638',
#   'Nom': 'RUSSELL Finn',
#   'Âge': '29',
#   'Taille': '183',
#   'Poids': '87',
#   'Nationalité': 'Ecosse',
#   'Poste': 'Ouverture',
#   'Matchs': '11',
#   'E': '',
#   'T': '',
#   'P': '1',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '579',
#   'Club': 'Racing 92'},
#  {'ID': '7091',
#   'Nom': 'BERJON Thomas',
#   'Âge': '23',
#   'Taille': '177',
#   'Poids': '87',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '9',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '233',
#   'Club': 'La Rochelle'},
#  {'ID': '4360',
#   'Nom': 'LE BAIL Clovis',
#   'Âge': '26',
#   'Taille': '173',
#   'Poids': '74',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '16',
#   'E': '3',
#   'T': '1',
#   'P': '3',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '857',
#   'Club': 'Pau'},
#  {'ID': '8225',
#   'Nom': 'CHEZEAU Jean',
#   'Âge': '20',
#   'Taille': '173',
#   'Poids': '74',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '2',
#   'Club': 'Racing 92'},
#  {'ID': '12330',
#   'Nom': 'LERAÎTRE Paul',
#   'Âge': '21',
#   'Taille': '187',
#   'Poids': '84',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '80',
#   'Club': 'Racing 92'},
#  {'ID': '12384',
#   'Nom': 'PEREZ Alexandre',
#   'Âge': '19',
#   'Taille': '173',
#   'Poids': '74',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '3',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '81',
#   'Club': 'Perpignan'},
#  {'ID': '12470',
#   'Nom': 'RIMET Liam',
#   'Âge': '18',
#   'Taille': '173',
#   'Poids': '74',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '3',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '11',
#   'Club': 'Lyon'},
#  {'ID': '507',
#   'Nom': 'MÉDARD Maxime',
#   'Âge': '35',
#   'Taille': '180',
#   'Poids': '88',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '11',
#   'E': '3',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '780',
#   'Club': 'Toulouse'},
#  {'ID': '5175',
#   'Nom': 'CARBONEL Louis',
#   'Âge': '23',
#   'Taille': '180',
#   'Poids': '88',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '14',
#   'E': '',
#   'T': '12',
#   'P': '23',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '770',
#   'Club': 'Toulon'},
#  {'ID': '5380',
#   'Nom': 'SMAÏLI Mathieu',
#   'Âge': '22',
#   'Taille': '180',
#   'Poids': '88',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '64',
#   'Club': 'Toulon'},
#  {'ID': '5090',
#   'Nom': 'KOLBE Cheslin',
#   'Âge': '28',
#   'Taille': '171',
#   'Poids': '80',
#   'Nationalité': 'Afrique du sud',
#   'Poste': 'Ailier',
#   'Matchs': '3',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '240',
#   'Club': 'Toulon'},
#  {'ID': '6069',
#   'Nom': 'LAPÈGUE Adrien',
#   'Âge': '23',
#   'Taille': '181',
#   'Poids': '88',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '7',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '483',
#   'Club': 'Paris'},
#  {'ID': '1193',
#   'Nom': 'DOMVO Darly',
#   'Âge': '29',
#   'Taille': '186',
#   'Poids': '86',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '7',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '376',
#   'Club': 'Biarritz'},
#  {'ID': '2053',
#   'Nom': 'BONNEVAL Arthur',
#   'Âge': '26',
#   'Taille': '182',
#   'Poids': '88',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '9',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '543',
#   'Club': 'Toulouse'},
#  {'ID': '5082',
#   'Nom': 'NTAMACK Romain',
#   'Âge': '22',
#   'Taille': '186',
#   'Poids': '86',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '11',
#   'E': '4',
#   'T': '7',
#   'P': '2',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '802',
#   'Club': 'Toulouse'},
#  {'ID': '8219',
#   'Nom': 'TIREFORT Valentin',
#   'Âge': '23',
#   'Taille': '186',
#   'Poids': '86',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '24',
#   'Club': 'Brive'},
#  {'ID': '8249',
#   'Nom': 'ALONSO Martin',
#   'Âge': '22',
#   'Taille': '182',
#   'Poids': '88',
#   'Nationalité': 'Espagne',
#   'Poste': 'Ailier',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '99',
#   'Club': 'La Rochelle'},
#  {'ID': '8654',
#   'Nom': 'FOURSANS-BOURDETTE Louis',
#   'Âge': '20',
#   'Taille': '171',
#   'Poids': '81',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '10',
#   'E': '',
#   'T': '7',
#   'P': '8',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '280',
#   'Club': 'Montpellier'},
#  {'ID': '1226',
#   'Nom': 'PAILLAUGUE Benoît',
#   'Âge': '34',
#   'Taille': '172',
#   'Poids': '74',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '3',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '70',
#   'Club': 'Montpellier'},
#  {'ID': '1903',
#   'Nom': 'PERRAUX Ilian',
#   'Âge': '29',
#   'Taille': '183',
#   'Poids': '88',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '9',
#   'E': '',
#   'T': '6',
#   'P': '9',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '462',
#   'Club': 'Biarritz'},
#  {'ID': '5332',
#   'Nom': 'LEYDS Dillyn',
#   'Âge': '29',
#   'Taille': '183',
#   'Poids': '88',
#   'Nationalité': 'Afrique du sud',
#   'Poste': 'Ailier',
#   'Matchs': '12',
#   'E': '5',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '871',
#   'Club': 'La Rochelle'},
#  {'ID': '1151',
#   'Nom': 'LOPEZ Camille',
#   'Âge': '32',
#   'Taille': '176',
#   'Poids': '88',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '11',
#   'E': '',
#   'T': '12',
#   'P': '20',
#   'D': '2',
#   'J': '',
#   'R': '',
#   'Temps': '629',
#   'Club': 'Clermont'},
#  {'ID': '1656',
#   'Nom': 'ABADIE Paul',
#   'Âge': '27',
#   'Taille': '176',
#   'Poids': '88',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '14',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '651',
#   'Club': 'Brive'},
#  {'ID': '4590',
#   'Nom': 'DEGHMACHE Sadek',
#   'Âge': '26',
#   'Taille': '176',
#   'Poids': '88',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '13',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '593',
#   'Club': 'Perpignan'},
#  {'ID': '1202',
#   'Nom': 'MACHENAUD Maxime',
#   'Âge': '33',
#   'Taille': '174',
#   'Poids': '87',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '14',
#   'E': '2',
#   'T': '19',
#   'P': '23',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '646',
#   'Club': 'Racing 92'},
#  {'ID': '5313',
#   'Nom': 'CORDIN Gervais',
#   'Âge': '23',
#   'Taille': '172',
#   'Poids': '73',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '11',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '704',
#   'Club': 'Toulon'},
#  {'ID': '6271',
#   'Nom': 'LEE Nico',
#   'Âge': '27',
#   'Taille': '180',
#   'Poids': '89',
#   'Nationalité': 'Afrique du sud',
#   'Poste': 'Centre',
#   'Matchs': '6',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '419',
#   'Club': 'Brive'},
#  {'ID': '10866',
#   'Nom': 'LACOSTE Tanguy',
#   'Âge': '19',
#   'Taille': '188',
#   'Poids': '85',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '18',
#   'Club': 'Brive'},
#  {'ID': '11059',
#   'Nom': 'NINIASHVILI Davit',
#   'Âge': '19',
#   'Taille': '186',
#   'Poids': '87',
#   'Nationalité': 'Géorgie',
#   'Poste': 'Ailier',
#   'Matchs': '11',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '511',
#   'Club': 'Lyon'},
#  {'ID': '4385',
#   'Nom': 'BARRY Steeve',
#   'Âge': '30',
#   'Taille': '181',
#   'Poids': '89',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '7',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '320',
#   'Club': 'Biarritz'},
#  {'ID': '5256',
#   'Nom': 'DARMON Thomas',
#   'Âge': '23',
#   'Taille': '181',
#   'Poids': '89',
#   'Nationalité': 'France',
#   'Poste': 'Centre',
#   'Matchs': '8',
#   'E': '',
#   'T': '1',
#   'P': '1',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '455',
#   'Club': 'Montpellier'},
#  {'ID': '6020',
#   'Nom': 'HENRY Zack',
#   'Âge': '27',
#   'Taille': '182',
#   'Poids': '89',
#   'Nationalité': 'Angleterre',
#   'Poste': 'Ouverture',
#   'Matchs': '10',
#   'E': '',
#   'T': '5',
#   'P': '16',
#   'D': '1',
#   'J': '',
#   'R': '',
#   'Temps': '680',
#   'Club': 'Pau'},
#  {'ID': '3789',
#   'Nom': 'MATSUSHIMA Kotaro',
#   'Âge': '28',
#   'Taille': '175',
#   'Poids': '88',
#   'Nationalité': 'Japon',
#   'Poste': 'Arrière',
#   'Matchs': '10',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '792',
#   'Club': 'Clermont'},
#  {'ID': '10755',
#   'Nom': 'ROZIÈRE Thomas',
#   'Âge': '21',
#   'Taille': '177',
#   'Poids': '89',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '7',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '220',
#   'Club': 'Clermont'},
#  {'ID': '7169',
#   'Nom': 'PAGE-RELO Martin',
#   'Âge': '23',
#   'Taille': '173',
#   'Poids': '71',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '3',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '7',
#   'Club': 'Toulouse'},
#  {'ID': '3698',
#   'Nom': 'ARRATÉ Alex',
#   'Âge': '24',
#   'Taille': '180',
#   'Poids': '90',
#   'Nationalité': 'France',
#   'Poste': 'Centre',
#   'Matchs': '13',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '806',
#   'Club': 'Paris'},
#  {'ID': '9971',
#   'Nom': 'JONAS Joe',
#   'Âge': '21',
#   'Taille': '180',
#   'Poids': '90',
#   'Nationalité': 'Afrique du sud',
#   'Poste': 'Arrière',
#   'Matchs': '8',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '403',
#   'Club': 'Biarritz'},
#  {'ID': '2477',
#   'Nom': 'KLEMENCZAK Olivier',
#   'Âge': '25',
#   'Taille': '181',
#   'Poids': '90',
#   'Nationalité': 'France',
#   'Poste': 'Centre',
#   'Matchs': '11',
#   'E': '3',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '544',
#   'Club': 'Racing 92'},
#  {'ID': '7001',
#   'Nom': 'FAVRE Jules',
#   'Âge': '22',
#   'Taille': '181',
#   'Poids': '90',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '14',
#   'E': '7',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '1057',
#   'Club': 'La Rochelle'},
#  {'ID': '581',
#   'Nom': 'ACÉBÈS Mathieu',
#   'Âge': '34',
#   'Taille': '182',
#   'Poids': '90',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '15',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '2',
#   'R': '',
#   'Temps': '1086',
#   'Club': 'Perpignan'},
#  {'ID': '3803',
#   'Nom': 'NANAI-WILLIAMS Tim',
#   'Âge': '32',
#   'Taille': '182',
#   'Poids': '90',
#   'Nationalité': 'Samoa',
#   'Poste': 'Arrière',
#   'Matchs': '10',
#   'E': '1',
#   'T': '2',
#   'P': '2',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '402',
#   'Club': 'Toulouse'},
#  {'ID': '10251',
#   'Nom': 'DANGLOT Jules',
#   'Âge': '20',
#   'Taille': '170',
#   'Poids': '74',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '12',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '276',
#   'Club': 'Toulon'},
#  {'ID': '4520',
#   'Nom': 'HALL James',
#   'Âge': '26',
#   'Taille': '173',
#   'Poids': '88',
#   'Nationalité': 'Afrique du sud',
#   'Poste': 'Mêlée',
#   'Matchs': '15',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '621',
#   'Club': 'Paris'},
#  {'ID': '4753',
#   'Nom': 'DOUGLAS Wesley',
#   'Âge': '25',
#   'Taille': '183',
#   'Poids': '90',
#   'Nationalité': 'Angleterre',
#   'Poste': 'Centre',
#   'Matchs': '7',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '446',
#   'Club': 'Brive'},
#  {'ID': '4760',
#   'Nom': 'LUCAS Pierre',
#   'Âge': '24',
#   'Taille': '183',
#   'Poids': '90',
#   'Nationalité': 'France',
#   'Poste': 'Centre',
#   'Matchs': '10',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '353',
#   'Club': 'Montpellier'},
#  {'ID': '5599',
#   'Nom': 'HERVÉ Enzo',
#   'Âge': '23',
#   'Taille': '177',
#   'Poids': '90',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '14',
#   'E': '2',
#   'T': '11',
#   'P': '26',
#   'D': '1',
#   'J': '',
#   'R': '1',
#   'Temps': '1001',
#   'Club': 'Brive'},
#  {'ID': '5600',
#   'Nom': 'VINCENT Arthur',
#   'Âge': '22',
#   'Taille': '183',
#   'Poids': '90',
#   'Nationalité': 'France',
#   'Poste': 'Centre',
#   'Matchs': '4',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '257',
#   'Club': 'Montpellier'},
#  {'ID': '9778',
#   'Nom': 'LEVRON Alexis',
#   'Âge': '21',
#   'Taille': '169',
#   'Poids': '76',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '7',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '152',
#   'Club': 'Pau'},
#  {'ID': '6053',
#   'Nom': 'DELIBES Dimitri',
#   'Âge': '22',
#   'Taille': '190',
#   'Poids': '85',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '4',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '151',
#   'Club': 'Toulouse'},
#  {'ID': '3493',
#   'Nom': 'LARREGAIN Thomas',
#   'Âge': '24',
#   'Taille': '184',
#   'Poids': '90',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '1',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '41',
#   'Club': 'Castres'},
#  {'ID': '4988',
#   'Nom': 'SEGONDS Joris',
#   'Âge': '24',
#   'Taille': '180',
#   'Poids': '91',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '16',
#   'E': '',
#   'T': '13',
#   'P': '41',
#   'D': '1',
#   'J': '',
#   'R': '',
#   'Temps': '1037',
#   'Club': 'Paris'},
#  {'ID': '1908',
#   'Nom': 'IMHOFF Juan',
#   'Âge': '33',
#   'Taille': '185',
#   'Poids': '90',
#   'Nationalité': 'Argentine',
#   'Poste': 'Ailier',
#   'Matchs': '14',
#   'E': '5',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '1038',
#   'Club': 'Racing 92'},
#  {'ID': '2501',
#   'Nom': 'FARNOUX Julien',
#   'Âge': '28',
#   'Taille': '185',
#   'Poids': '90',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '107',
#   'Club': 'Perpignan'},
#  {'ID': '3543',
#   'Nom': 'HOLMES Zack',
#   'Âge': '31',
#   'Taille': '175',
#   'Poids': '90',
#   'Nationalité': 'Australie',
#   'Poste': 'Ouverture',
#   'Matchs': '12',
#   'E': '1',
#   'T': '4',
#   'P': '6',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '599',
#   'Club': 'Toulouse'},
#  {'ID': '2454',
#   'Nom': 'HAMDAOUI Kylan',
#   'Âge': '27',
#   'Taille': '182',
#   'Poids': '91',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '14',
#   'E': '3',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '1016',
#   'Club': 'Paris'},
#  {'ID': '7320',
#   'Nom': 'RODOR Matteo',
#   'Âge': '22',
#   'Taille': '170',
#   'Poids': '72',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '10',
#   'E': '1',
#   'T': '3',
#   'P': '1',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '346',
#   'Club': 'Perpignan'},
#  {'ID': '339',
#   'Nom': 'TRINH-DUC François',
#   'Âge': '35',
#   'Taille': '186',
#   'Poids': '90',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '15',
#   'E': '',
#   'T': '8',
#   'P': '12',
#   'D': '3',
#   'J': '1',
#   'R': '',
#   'Temps': '636',
#   'Club': 'Bordeaux'},
#  {'ID': '1175',
#   'Nom': 'LARANJEIRA Thomas',
#   'Âge': '29',
#   'Taille': '186',
#   'Poids': '90',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '10',
#   'E': '',
#   'T': '4',
#   'P': '9',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '540',
#   'Club': 'Brive'},
#  {'ID': '3566',
#   'Nom': 'NICOUÉ Alexandre',
#   'Âge': '25',
#   'Taille': '184',
#   'Poids': '91',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '20',
#   'Club': 'Biarritz'},
#  {'ID': '5330',
#   'Nom': 'RHULE Raymond',
#   'Âge': '29',
#   'Taille': '189',
#   'Poids': '88',
#   'Nationalité': 'Afrique du sud',
#   'Poste': 'Ailier',
#   'Matchs': '14',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '951',
#   'Club': 'La Rochelle'},
#  {'ID': '9771',
#   'Nom': 'CHAMP Paul',
#   'Âge': '21',
#   'Taille': '188',
#   'Poids': '89',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '105',
#   'Club': 'Paris'},
#  {'ID': '1330',
#   'Nom': 'KOCKOTT Rory',
#   'Âge': '35',
#   'Taille': '180',
#   'Poids': '92',
#   'Nationalité': 'Afrique du sud',
#   'Poste': 'Mêlée',
#   'Matchs': '11',
#   'E': '2',
#   'T': '',
#   'P': '2',
#   'D': '',
#   'J': '2',
#   'R': '',
#   'Temps': '468',
#   'Club': 'Castres'},
#  {'ID': '2874',
#   'Nom': 'OLDING Stuart',
#   'Âge': '28',
#   'Taille': '180',
#   'Poids': '92',
#   'Nationalité': 'Irlande',
#   'Poste': 'Centre',
#   'Matchs': '8',
#   'E': '',
#   'T': '2',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '539',
#   'Club': 'Brive'},
#  {'ID': '2883',
#   'Nom': 'DUCUING Nans',
#   'Âge': '30',
#   'Taille': '185',
#   'Poids': '91',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '8',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '490',
#   'Club': 'Bordeaux'},
#  {'ID': '4664',
#   'Nom': 'UBERTI Pablo',
#   'Âge': '24',
#   'Taille': '185',
#   'Poids': '91',
#   'Nationalité': 'France',
#   'Poste': 'Centre',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '62',
#   'Club': 'Bordeaux'},
#  {'ID': '5042',
#   'Nom': 'SOPOAGA Lima',
#   'Âge': '31',
#   'Taille': '175',
#   'Poids': '91',
#   'Nationalité': 'Nouvelle-Zélande',
#   'Poste': 'Ouverture',
#   'Matchs': '8',
#   'E': '',
#   'T': '7',
#   'P': '4',
#   'D': '1',
#   'J': '',
#   'R': '',
#   'Temps': '295',
#   'Club': 'Lyon'},
#  {'ID': '6346',
#   'Nom': 'LEBEL Matthis',
#   'Âge': '22',
#   'Taille': '185',
#   'Poids': '91',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '11',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '833',
#   'Club': 'Toulouse'},
#  {'ID': '6408',
#   'Nom': 'MALLIA Juan Cruz',
#   'Âge': '25',
#   'Taille': '182',
#   'Poids': '92',
#   'Nationalité': 'Argentine',
#   'Poste': 'Centre',
#   'Matchs': '5',
#   'E': '4',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '277',
#   'Club': 'Toulouse'},
#  {'ID': '6664',
#   'Nom': "PAIA'AUA Duncan",
#   'Âge': '27',
#   'Taille': '183',
#   'Poids': '92',
#   'Nationalité': 'Nouvelle-Zélande',
#   'Poste': 'Centre',
#   'Matchs': '6',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '470',
#   'Club': 'Toulon'},
#  {'ID': '2029',
#   'Nom': 'LE BAIL Jules',
#   'Âge': '30',
#   'Taille': '168',
#   'Poids': '85',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '8',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '162',
#   'Club': 'La Rochelle'},
#  {'ID': '5148',
#   'Nom': 'SALLES Thomas',
#   'Âge': '25',
#   'Taille': '186',
#   'Poids': '91',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '6',
#   'E': '1',
#   'T': '',
#   'P': '1',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '390',
#   'Club': 'Toulon'},
#  {'ID': '1774',
#   'Nom': 'IRIBAREN Teddy',
#   'Âge': '31',
#   'Taille': '170',
#   'Poids': '70',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '2',
#   'E': '',
#   'T': '2',
#   'P': '1',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '84',
#   'Club': 'Racing 92'},
#  {'ID': '8224',
#   'Nom': 'BARRÉ Léo',
#   'Âge': '19',
#   'Taille': '189',
#   'Poids': '89',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '13',
#   'E': '',
#   'T': '',
#   'P': '5',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '496',
#   'Club': 'Paris'},
#  {'ID': '1117',
#   'Nom': 'PLISSON Jules',
#   'Âge': '30',
#   'Taille': '184',
#   'Poids': '92',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '6',
#   'E': '',
#   'T': '3',
#   'P': '10',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '300',
#   'Club': 'La Rochelle'},
#  {'ID': '3905',
#   'Nom': 'KERR-BARLOW Tawera',
#   'Âge': '31',
#   'Taille': '187',
#   'Poids': '91',
#   'Nationalité': 'Nouvelle-Zélande',
#   'Poste': 'Mêlée',
#   'Matchs': '14',
#   'E': '5',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '877',
#   'Club': 'La Rochelle'},
#  {'ID': '3991',
#   'Nom': 'IKPEFAN Daniel',
#   'Âge': '28',
#   'Taille': '185',
#   'Poids': '92',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '5',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '378',
#   'Club': 'Pau'},
#  {'ID': '1076',
#   'Nom': 'AGUILLON Pierre',
#   'Âge': '34',
#   'Taille': '180',
#   'Poids': '93',
#   'Nationalité': 'France',
#   'Poste': 'Centre',
#   'Matchs': '6',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '135',
#   'Club': 'Castres'},
#  {'ID': '7728',
#   'Nom': 'VILLIÈRE Gabin',
#   'Âge': '26',
#   'Taille': '180',
#   'Poids': '93',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '6',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '480',
#   'Club': 'Toulon'},
#  {'ID': '9866',
#   'Nom': 'BOTITU Vilimoni',
#   'Âge': '23',
#   'Taille': '179',
#   'Poids': '93',
#   'Nationalité': 'Fidji',
#   'Poste': 'Centre',
#   'Matchs': '12',
#   'E': '3',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '847',
#   'Club': 'Castres'},
#  {'ID': '1079',
#   'Nom': 'FOFANA Wesley',
#   'Âge': '34',
#   'Taille': '182',
#   'Poids': '93',
#   'Nationalité': 'France',
#   'Poste': 'Centre',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '73',
#   'Club': 'Clermont'},
#  {'ID': '2644',
#   'Nom': 'BOTICA Ben',
#   'Âge': '32',
#   'Taille': '178',
#   'Poids': '93',
#   'Nationalité': 'Nouvelle-Zélande',
#   'Poste': 'Ouverture',
#   'Matchs': '7',
#   'E': '1',
#   'T': '8',
#   'P': '10',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '469',
#   'Club': 'Castres'},
#  {'ID': '10749',
#   'Nom': 'PARISIEN Alfred',
#   'Âge': '20',
#   'Taille': '182',
#   'Poids': '93',
#   'Nationalité': 'France',
#   'Poste': 'Centre',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '117',
#   'Club': 'Lyon'},
#  {'ID': '2280',
#   'Nom': 'HANRAHAN JJ',
#   'Âge': '29',
#   'Taille': '183',
#   'Poids': '93',
#   'Nationalité': 'Irlande',
#   'Poste': 'Ouverture',
#   'Matchs': '14',
#   'E': '3',
#   'T': '1',
#   'P': '4',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '575',
#   'Club': 'Clermont'},
#  {'ID': '7397',
#   'Nom': 'GARBISI Paolo',
#   'Âge': '21',
#   'Taille': '183',
#   'Poids': '93',
#   'Nationalité': 'Italie',
#   'Poste': 'Ouverture',
#   'Matchs': '11',
#   'E': '',
#   'T': '17',
#   'P': '28',
#   'D': '1',
#   'J': '',
#   'R': '',
#   'Temps': '795',
#   'Club': 'Montpellier'},
#  {'ID': '7504',
#   'Nom': 'CHOCOBARES Santiago',
#   'Âge': '22',
#   'Taille': '188',
#   'Poids': '91',
#   'Nationalité': 'Argentine',
#   'Poste': 'Centre',
#   'Matchs': '2',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '160',
#   'Club': 'Toulouse'},
#  {'ID': '8290',
#   'Nom': 'IDJELLIDAINE Théo',
#   'Âge': '20',
#   'Taille': '168',
#   'Poids': '71',
#   'Nationalité': 'France',
#   'Poste': 'Mêlée',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '0',
#   'Club': 'Toulouse'},
#  {'ID': '10468',
#   'Nom': 'OBATOYINBO Harrison',
#   'Âge': '21',
#   'Taille': '187',
#   'Poids': '92',
#   'Nationalité': 'Angleterre',
#   'Poste': 'Ailier',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '139',
#   'Club': 'Toulon'},
#  {'ID': '1248',
#   'Nom': 'MARTIN Vincent',
#   'Âge': '29',
#   'Taille': '185',
#   'Poids': '93',
#   'Nationalité': 'France',
#   'Poste': 'Centre',
#   'Matchs': '5',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '165',
#   'Club': 'Biarritz'},
#  {'ID': '1350',
#   'Nom': 'LONCA Romain',
#   'Âge': '30',
#   'Taille': '190',
#   'Poids': '90',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '13',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '766',
#   'Club': 'Biarritz'},
#  {'ID': '8436',
#   'Nom': 'REBBADJ Rayan',
#   'Âge': '22',
#   'Taille': '190',
#   'Poids': '90',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '1',
#   'Temps': '158',
#   'Club': 'Toulon'},
#  {'ID': '4169',
#   'Nom': 'REILHAC Yvan',
#   'Âge': '26',
#   'Taille': '182',
#   'Poids': '94',
#   'Nationalité': 'France',
#   'Poste': 'Centre',
#   'Matchs': '4',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '137',
#   'Club': 'Montpellier'},
#  {'ID': '12297',
#   'Nom': 'MASSÉ Gatien',
#   'Âge': '19',
#   'Taille': '182',
#   'Poids': '94',
#   'Nationalité': 'France',
#   'Poste': 'Centre',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '42',
#   'Club': 'Bordeaux'},
#  {'ID': '1140',
#   'Nom': 'DOUSSAIN Jean-Marc',
#   'Âge': '31',
#   'Taille': '174',
#   'Poids': '93',
#   'Nationalité': 'France',
#   'Poste': 'Ouverture',
#   'Matchs': '11',
#   'E': '1',
#   'T': '6',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '390',
#   'Club': 'Lyon'},
#  {'ID': '8875',
#   'Nom': 'DUBOIS Lucas',
#   'Âge': '23',
#   'Taille': '188',
#   'Poids': '92',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '11',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '639',
#   'Club': 'Perpignan'},
#  {'ID': '12252',
#   'Nom': 'VAITULUKINA Emmanuel',
#   'Âge': '20',
#   'Taille': '183',
#   'Poids': '94',
#   'Nationalité': 'France',
#   'Poste': 'Centre',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '30',
#   'Club': 'Perpignan'},
#  {'ID': '7310',
#   'Nom': 'PINTO Vincent',
#   'Âge': '22',
#   'Taille': '187',
#   'Poids': '93',
#   'Nationalité': 'France',
#   'Poste': 'Ailier',
#   'Matchs': '6',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '246',
#   'Club': 'Pau'},
#  {'ID': '5151',
#   'Nom': 'COLOMBET Mathias',
#   'Âge': '24',
#   'Taille': '189',
#   'Poids': '92',
#   'Nationalité': 'France',
#   'Poste': 'Arrière',
#   'Matchs': '14',
# ...
#   'Âge': '21',
#   'Taille': '190',
#   'Poids': '124',
#   'Nationalité': 'France',
#   'Poste': '3ème ligne',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '53',
#   'Club': 'Racing 92'},
#  {'ID': '4364',
#   'Nom': 'PAÏVA Thierry',
#   'Âge': '26',
#   'Taille': '184',
#   'Poids': '125',
#   'Nationalité': 'France',
#   'Poste': 'Pilier',
#   'Matchs': '13',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '603',
#   'Club': 'Bordeaux'},
#  {'ID': '5589',
#   'Nom': "FISI'IHOI Siegfried",
#   'Âge': '34',
#   'Taille': '184',
#   'Poids': '125',
#   'Nationalité': 'Tonga',
#   'Poste': 'Pilier',
#   'Matchs': '14',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '790',
#   'Club': 'Pau'},
#  {'ID': '6074',
#   'Nom': 'MILLAR Guy',
#   'Âge': '29',
#   'Taille': '186',
#   'Poids': '125',
#   'Nationalité': 'Australie',
#   'Poste': 'Pilier',
#   'Matchs': '10',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '2',
#   'R': '',
#   'Temps': '624',
#   'Club': 'Biarritz'},
#  {'ID': '1094',
#   'Nom': 'JEDRASIAK Paul',
#   'Âge': '29',
#   'Taille': '200',
#   'Poids': '121',
#   'Nationalité': 'France',
#   'Poste': '2ème ligne',
#   'Matchs': '10',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '509',
#   'Club': 'Clermont'},
#  {'ID': '5366',
#   'Nom': 'PAPIDZE Guram',
#   'Âge': '24',
#   'Taille': '187',
#   'Poids': '125',
#   'Nationalité': 'Géorgie',
#   'Poste': 'Pilier',
#   'Matchs': '9',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '283',
#   'Club': 'La Rochelle'},
#  {'ID': '5869',
#   'Nom': 'CUMMINS Steven',
#   'Âge': '29',
#   'Taille': '202',
#   'Poids': '120',
#   'Nationalité': 'Australie',
#   'Poste': '2ème ligne',
#   'Matchs': '14',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '784',
#   'Club': 'Pau'},
#  {'ID': '2338',
#   'Nom': 'HANNOYER Théo',
#   'Âge': '25',
#   'Taille': '198',
#   'Poids': '122',
#   'Nationalité': 'France',
#   'Poste': '2ème ligne',
#   'Matchs': '6',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '203',
#   'Club': 'Castres'},
#  {'ID': '4085',
#   'Nom': 'DELANNOY Julien',
#   'Âge': '26',
#   'Taille': '198',
#   'Poids': '123',
#   'Nationalité': 'France',
#   'Poste': '2ème ligne',
#   'Matchs': '6',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '329',
#   'Club': 'Pau'},
#  {'ID': '8246',
#   'Nom': 'DUGUID Tyler',
#   'Âge': '21',
#   'Taille': '196',
#   'Poids': '124',
#   'Nationalité': 'Canada',
#   'Poste': '2ème ligne',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '59',
#   'Club': 'Montpellier'},
#  {'ID': '5008',
#   'Nom': 'TIMANI Lopeti',
#   'Âge': '31',
#   'Taille': '193',
#   'Poids': '125',
#   'Nationalité': 'Tonga',
#   'Poste': '3ème ligne',
#   'Matchs': '9',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '380',
#   'Club': 'Toulon'},
#  {'ID': '5364',
#   'Nom': 'YAMÉOGO Kévin',
#   'Âge': '24',
#   'Taille': '193',
#   'Poids': '125',
#   'Nationalité': 'France',
#   'Poste': 'Pilier',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '33',
#   'Club': 'Pau'},
#  {'ID': '7501',
#   'Nom': 'PAULOS Lucas',
#   'Âge': '24',
#   'Taille': '199',
#   'Poids': '123',
#   'Nationalité': 'Argentine',
#   'Poste': '2ème ligne',
#   'Matchs': '8',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '1',
#   'Temps': '486',
#   'Club': 'Brive'},
#  {'ID': '2799',
#   'Nom': 'COBILAS Vadim',
#   'Âge': '38',
#   'Taille': '183',
#   'Poids': '127',
#   'Nationalité': 'Moldavie',
#   'Poste': 'Pilier',
#   'Matchs': '10',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '383',
#   'Club': 'Bordeaux'},
#  {'ID': '4681',
#   'Nom': 'HAOUAS Mohamed',
#   'Âge': '27',
#   'Taille': '185',
#   'Poids': '127',
#   'Nationalité': 'France',
#   'Poste': 'Pilier',
#   'Matchs': '10',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '510',
#   'Club': 'Montpellier'},
#  {'ID': '3763',
#   'Nom': 'ETZEBETH Eben',
#   'Âge': '30',
#   'Taille': '203',
#   'Poids': '122',
#   'Nationalité': 'Afrique du sud',
#   'Poste': '2ème ligne',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '80',
#   'Club': 'Toulon'},
#  {'ID': '2218',
#   'Nom': 'HERRERA Ramiro',
#   'Âge': '33',
#   'Taille': '194',
#   'Poids': '126',
#   'Nationalité': 'Argentine',
#   'Poste': 'Pilier',
#   'Matchs': '8',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '209',
#   'Club': 'La Rochelle'},
#  {'ID': '4793',
#   'Nom': 'CAREY Conor',
#   'Âge': '30',
#   'Taille': '183',
#   'Poids': '128',
#   'Nationalité': 'Irlande',
#   'Poste': 'Pilier',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '78',
#   'Club': 'Perpignan'},
#  {'ID': '2696',
#   'Nom': 'DOUGLAS Kane',
#   'Âge': '32',
#   'Taille': '202',
#   'Poids': '123',
#   'Nationalité': 'Australie',
#   'Poste': '2ème ligne',
#   'Matchs': '14',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '1028',
#   'Club': 'Bordeaux'},
#  {'ID': '5002',
#   'Nom': 'ARNOLD Rory',
#   'Âge': '31',
#   'Taille': '208',
#   'Poids': '120',
#   'Nationalité': 'Australie',
#   'Poste': '2ème ligne',
#   'Matchs': '12',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '678',
#   'Club': 'Toulouse'},
#  {'ID': '7138',
#   'Nom': 'KPOKU Joel',
#   'Âge': '22',
#   'Taille': '196',
#   'Poids': '126',
#   'Nationalité': 'Angleterre',
#   'Poste': '2ème ligne',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '33',
#   'Club': 'Lyon'},
#  {'ID': '2634',
#   'Nom': 'NAKARAWA Leone',
#   'Âge': '34',
#   'Taille': '200',
#   'Poids': '125',
#   'Nationalité': 'Fidji',
#   'Poste': '2ème ligne',
#   'Matchs': '10',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '2',
#   'R': '',
#   'Temps': '688',
#   'Club': 'Toulon'},
#  {'ID': '4332',
#   'Nom': 'CAPELLI Mickaël',
#   'Âge': '24',
#   'Taille': '198',
#   'Poids': '126',
#   'Nationalité': 'France',
#   'Poste': '2ème ligne',
#   'Matchs': '2',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '86',
#   'Club': 'Montpellier'},
#  {'ID': '3219',
#   'Nom': 'BROOKES Kieran',
#   'Âge': '31',
#   'Taille': '188',
#   'Poids': '129',
#   'Nationalité': 'Angleterre',
#   'Poste': 'Pilier',
#   'Matchs': '13',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '527',
#   'Club': 'Toulon'},
#  {'ID': '1144',
#   'Nom': 'TAOFIFENUA Sébastien',
#   'Âge': '29',
#   'Taille': '178',
#   'Poids': '130',
#   'Nationalité': 'France',
#   'Poste': 'Pilier',
#   'Matchs': '11',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '419',
#   'Club': 'Lyon'},
#  {'ID': '3855',
#   'Nom': 'FAUMUINA Charlie',
#   'Âge': '35',
#   'Taille': '184',
#   'Poids': '130',
#   'Nationalité': 'Nouvelle-Zélande',
#   'Poste': 'Pilier',
#   'Matchs': '10',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '492',
#   'Club': 'Toulouse'},
#  {'ID': '9889',
#   'Nom': 'AMATOSERO Miles',
#   'Âge': '19',
#   'Taille': '203',
#   'Poids': '125',
#   'Nationalité': 'Australie',
#   'Poste': '2ème ligne',
#   'Matchs': '4',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '163',
#   'Club': 'Clermont'},
#  {'ID': '3312',
#   'Nom': 'WILLEMSE Paul',
#   'Âge': '29',
#   'Taille': '201',
#   'Poids': '126',
#   'Nationalité': 'Afrique du sud',
#   'Poste': '2ème ligne',
#   'Matchs': '7',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '2',
#   'R': '',
#   'Temps': '379',
#   'Club': 'Montpellier'},
#  {'ID': '5708',
#   'Nom': 'MAHU Andreï',
#   'Âge': '30',
#   'Taille': '205',
#   'Poids': '124',
#   'Nationalité': 'Moldavie',
#   'Poste': '2ème ligne',
#   'Matchs': '12',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '708',
#   'Club': 'Perpignan'},
#  {'ID': '6023',
#   'Nom': 'ALO-EMILE Moses',
#   'Âge': '22',
#   'Taille': '187',
#   'Poids': '130',
#   'Nationalité': 'Australie',
#   'Poste': 'Pilier',
#   'Matchs': '13',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '591',
#   'Club': 'Paris'},
#  {'ID': '1300',
#   'Nom': 'CHILACHAVA Levan',
#   'Âge': '30',
#   'Taille': '188',
#   'Poids': '130',
#   'Nationalité': 'Géorgie',
#   'Poste': 'Pilier',
#   'Matchs': '14',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '345',
#   'Club': 'Castres'},
#  {'ID': '1912',
#   'Nom': 'CHALUREAU Bastien',
#   'Âge': '30',
#   'Taille': '202',
#   'Poids': '126',
#   'Nationalité': 'France',
#   'Poste': '2ème ligne',
#   'Matchs': '13',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '2',
#   'R': '1',
#   'Temps': '723',
#   'Club': 'Montpellier'},
#  {'ID': '1147',
#   'Nom': 'TAOFIFENUA Romain',
#   'Âge': '31',
#   'Taille': '200',
#   'Poids': '127',
#   'Nationalité': 'France',
#   'Poste': '2ème ligne',
#   'Matchs': '10',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '624',
#   'Club': 'Lyon'},
#  {'ID': '2376',
#   'Nom': 'MOREAUX Victor',
#   'Âge': '28',
#   'Taille': '200',
#   'Poids': '127',
#   'Nationalité': 'France',
#   'Poste': '2ème ligne',
#   'Matchs': '8',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '2',
#   'R': '',
#   'Temps': '237',
#   'Club': 'Racing 92'},
#  {'ID': '3387',
#   'Nom': 'ALO-EMILE Paul',
#   'Âge': '30',
#   'Taille': '180',
#   'Poids': '132',
#   'Nationalité': 'Australie',
#   'Poste': 'Pilier',
#   'Matchs': '11',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '1',
#   'Temps': '536',
#   'Club': 'Paris'},
#  {'ID': '1082',
#   'Nom': 'TOLOFUA Christopher',
#   'Âge': '28',
#   'Taille': '182',
#   'Poids': '132',
#   'Nationalité': 'France',
#   'Poste': 'Talonneur',
#   'Matchs': '3',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '130',
#   'Club': 'Toulon'},
#  {'ID': '3813',
#   'Nom': 'LAMOSITELE Titi',
#   'Âge': '27',
#   'Taille': '183',
#   'Poids': '132',
#   'Nationalité': 'Etats-Unis',
#   'Poste': 'Pilier',
#   'Matchs': '11',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '426',
#   'Club': 'Montpellier'},
#  {'ID': '4766',
#   'Nom': 'TAFILI Paulo',
#   'Âge': '26',
#   'Taille': '183',
#   'Poids': '132',
#   'Nationalité': 'France',
#   'Poste': 'Pilier',
#   'Matchs': '10',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '372',
#   'Club': 'Toulouse'},
#  {'ID': '1146',
#   'Nom': 'VAHAAMAHINA Sébastien',
#   'Âge': '30',
#   'Taille': '203',
#   'Poids': '127',
#   'Nationalité': 'France',
#   'Poste': '2ème ligne',
#   'Matchs': '10',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '697',
#   'Club': 'Clermont'},
#  {'ID': '4382',
#   'Nom': 'JOLMÈS Thomas',
#   'Âge': '26',
#   'Taille': '204',
#   'Poids': '127',
#   'Nationalité': 'France',
#   'Poste': '2ème ligne',
#   'Matchs': '14',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '621',
#   'Club': 'Bordeaux'},
#  {'ID': '1085',
#   'Nom': 'TEKORI Iosefa',
#   'Âge': '38',
#   'Taille': '198',
#   'Poids': '130',
#   'Nationalité': 'Samoa',
#   'Poste': '2ème ligne',
#   'Matchs': '7',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '1',
#   'Temps': '158',
#   'Club': 'Toulouse'},
#  {'ID': '1476',
#   'Nom': 'HOUNKPATIN Wilfrid',
#   'Âge': '30',
#   'Taille': '192',
#   'Poids': '132',
#   'Nationalité': 'France',
#   'Poste': 'Pilier',
#   'Matchs': '15',
#   'E': '4',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '851',
#   'Club': 'Castres'},
#  {'ID': '4493',
#   'Nom': 'BRENNAN Daniel',
#   'Âge': '23',
#   'Taille': '192',
#   'Poids': '132',
#   'Nationalité': 'Irlande',
#   'Poste': 'Pilier',
#   'Matchs': '10',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '279',
#   'Club': 'Brive'},
#  {'ID': '2367',
#   'Nom': 'LAVANINI Tomás',
#   'Âge': '29',
#   'Taille': '202',
#   'Poids': '130',
#   'Nationalité': 'Argentine',
#   'Poste': '2ème ligne',
#   'Matchs': '5',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '2',
#   'R': '',
#   'Temps': '332',
#   'Club': 'Clermont'},
#  {'ID': '6688',
#   'Nom': 'ARNOLD Richie',
#   'Âge': '31',
#   'Taille': '208',
#   'Poids': '127',
#   'Nationalité': 'Australie',
#   'Poste': '2ème ligne',
#   'Matchs': '9',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '411',
#   'Club': 'Toulouse'},
#  {'ID': '5276',
#   'Nom': 'COLOMBE Georges-Henri',
#   'Âge': '23',
#   'Taille': '193',
#   'Poids': '135',
#   'Nationalité': 'France',
#   'Poste': 'Pilier',
#   'Matchs': '10',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '433',
#   'Club': 'Racing 92'},
#  {'ID': '12327',
#   'Nom': 'VAIOTU Aston',
#   'Âge': '19',
#   'Taille': '202',
#   'Poids': '133',
#   'Nationalité': 'Australie',
#   'Poste': '2ème ligne',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '4',
#   'Club': 'Racing 92'},
#  {'ID': '1416',
#   'Nom': 'ALIOUAT Johan',
#   'Âge': '29',
#   'Taille': '197',
#   'Poids': '135',
#   'Nationalité': 'France',
#   'Poste': '2ème ligne',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '73',
#   'Club': 'Biarritz'},
#  {'ID': '4994',
#   'Nom': "FA'ASO'O So'otala",
#   'Âge': '27',
#   'Taille': '194',
#   'Poids': '136',
#   'Nationalité': 'Samoa',
#   'Poste': '3ème ligne',
#   'Matchs': '7',
#   'E': '3',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '383',
#   'Club': 'Brive'},
#  {'ID': '7512',
#   'Nom': 'VAN DER MESCHT JJ',
#   'Âge': '22',
#   'Taille': '200',
#   'Poids': '135',
#   'Nationalité': 'Afrique du sud',
#   'Poste': '2ème ligne',
#   'Matchs': '15',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '2',
#   'R': '',
#   'Temps': '500',
#   'Club': 'Paris'},
#  {'ID': '5125',
#   'Nom': "ALAINU'UESE Brian",
#   'Âge': '27',
#   'Taille': '202',
#   'Poids': '135',
#   'Nationalité': 'Samoa',
#   'Poste': '2ème ligne',
#   'Matchs': '10',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '621',
#   'Club': 'Toulon'},
#  {'ID': '1139',
#   'Nom': 'GUILLAMON Antoine',
#   'Âge': '30',
#   'Taille': '192',
#   'Poids': '139',
#   'Nationalité': 'France',
#   'Poste': 'Pilier',
#   'Matchs': '5',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '154',
#   'Club': 'Castres'},
#  {'ID': '4378',
#   'Nom': 'OZ Ali',
#   'Âge': '26',
#   'Taille': '193',
#   'Poids': '140',
#   'Nationalité': 'France',
#   'Poste': 'Pilier',
#   'Matchs': '8',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '428',
#   'Club': 'Racing 92'},
#  {'ID': '3888',
#   'Nom': 'SKELTON Will',
#   'Âge': '29',
#   'Taille': '203',
#   'Poids': '140',
#   'Nationalité': 'Samoa',
#   'Poste': '2ème ligne',
#   'Matchs': '8',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '1',
#   'Temps': '543',
#   'Club': 'La Rochelle'},
#  {'ID': '4428',
#   'Nom': 'SCLAVI Joel',
#   'Âge': '27',
#   'Taille': '190',
#   'Poids': '144',
#   'Nationalité': 'Argentine',
#   'Poste': 'Pilier',
#   'Matchs': '2',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '91',
#   'Club': 'La Rochelle'},
#  {'ID': '1497',
#   'Nom': 'HAMADACHE Malik',
#   'Âge': '33',
#   'Taille': '193',
#   'Poids': '145',
#   'Nationalité': 'France',
#   'Poste': 'Pilier',
#   'Matchs': '1',
#   'E': '',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '7',
#   'Club': 'Montpellier'},
#  {'ID': '1625',
#   'Nom': 'ATONIO Uini',
#   'Âge': '31',
#   'Taille': '196',
#   'Poids': '145',
#   'Nationalité': 'Nouvelle-Zélande',
#   'Poste': 'Pilier',
#   'Matchs': '13',
#   'E': '2',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '1',
#   'R': '',
#   'Temps': '685',
#   'Club': 'La Rochelle'},
#  {'ID': '3391',
#   'Nom': 'TAMEIFUNA Ben',
#   'Âge': '30',
#   'Taille': '182',
#   'Poids': '148',
#   'Nationalité': 'Nouvelle-Zélande',
#   'Poste': 'Pilier',
#   'Matchs': '14',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '568',
#   'Club': 'Bordeaux'},
#  {'ID': '7337',
#   'Nom': 'MEAFOU Emmanuel',
#   'Âge': '23',
#   'Taille': '203',
#   'Poids': '145',
#   'Nationalité': 'Australie',
#   'Poste': '2ème ligne',
#   'Matchs': '5',
#   'E': '1',
#   'T': '',
#   'P': '',
#   'D': '',
#   'J': '',
#   'R': '',
#   'Temps': '303',
#   'Club': 'Toulouse'}]
