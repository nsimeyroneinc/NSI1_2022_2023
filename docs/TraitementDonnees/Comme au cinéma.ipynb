# %% [markdown]
# # <p style="text-align:center;color:red;font-size:36px">Comme au cinéma...</p>

# %% [markdown]
# Entrer le code qui permet de faire les affichages demandés. Il se peut que vous ayez besoin de créé des sous dataframes, n'hésitez pas à ajouter un commentaire pour expliquer ce qu'il contient.

# %%
import pandas as pd
import numpy as np
films=pd.read_csv('films.csv', delimiter=';' ,encoding='utf8')
films.head()

# %% [markdown]
# 1. Combien de films sont répertoriés?

# %% [markdown]
# *votre réponse ici*

# %% [markdown]
# 2. Afficher les titres des 10 films les plus longs :

# %% [markdown]
# 3. Affciher la liste des 5 films qui ont rapporté le moins.

# %% [markdown]
# 4. Combien de langues sont représentées?

# %% [markdown]
# 5. Afficher la liste des langues.

# %% [markdown]
# 6. Combien y a t il de films par langues?

# %% [markdown]
# `groupby` regroupe les résultats partageant une donnée commune. Elle ermet ensuite de compter le nombre d'apparition de cette donnée.
# `DF.groupby(DF["champ de tri"]).count()` : compte le nombre de d'occurence par element du champ

# %% [markdown]
# 7. Quelle est l'année qui a le plus de films?
# *une seule année doit s'afficher pas uen liste même triée*

# %% [markdown]
# Nous allons utiliser un deuxieme fichier contenant les liste des réalisateurs.
# realisateurs.csv.
# 8. Ouvrir le fichier et placer les données dans un dataframe `realistauers`.

# %% [markdown]
# 9. Combien de réalisateurs contient la base de données?

# %% [markdown]
# 10. Fusionner les deux tables.

# %% [markdown]
# 11. Afficher la liste des 10 réalisateurs ayant rapporté les revenus de films les pplus importants

# %% [markdown]
# Que remarque -t-on?

# %% [markdown]
# *votre réponse ici*

# %% [markdown]
# Pour cela nous allons utiliser deux fonctions de pandas.
# `DF.duplicates(subset='champ sur lequel on compte').sum() `: compte le nombre de doublons du champ dans le dataframe appelé DF
# `DF.drop_duplicates(subset=['champ sur lequel on travaille'], keep='first')` : supprime les doublons dans ce champ et ne garde que le dernier (keep='last') ou le premier (keep='first').
# Nous souhaitons ici conserver le dernier film réalisé.
# Combien y a-t-il réellement de réalisateurs dans la base de données?

# %% [markdown]
# 12. Calculer et afficher la moyenne des revenus par réalisateur.
# *N'afficher que les 10 premiers.*
